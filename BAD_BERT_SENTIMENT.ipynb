# %% [markdown]
# # Import Statements

# %%
import re
import sklearn
import pandas as pd
import gensim
import numpy as np
import nltk
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
from gensim import corpora, models
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation as LDA
from sklearn.naive_bayes import MultinomialNB
from sklearn.decomposition import TruncatedSVD, NMF
from sklearn.metrics import classification_report
from simpletransformers.classification import ClassificationModel, ClassificationArgs
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %% [markdown]
# # Data Preperation

# %%
# Importing all related Datasets, cleaning, pre-processing and creating a balanced dataset 
# We know that our dataset is balanced across 3 categories of sports, movie and books
# So each category will be assigned 1/3 of the dataset...

fifa_df = pd.read_csv('fifa.csv')
fifa_df.dropna(inplace=True)
fifa_df = fifa_df.drop(['Unnamed: 0', 'Date Created', 'Number of Likes', 'Source of Tweet', 'Sentiment'],axis = 1)
fifa_df.rename(columns={'Tweet':'text'}, inplace=True)
fifa_df['topic'] = 'sports'
fifa = fifa_df.sample(n=1000, random_state=1)

# %%
fifa
# Out:
#                                                     text   topic
# 21402  a fan chant jsjzhdhd #Dreamers2022 #WorldCup20...  sports
# 3075   Argentina since day 1🇦🇷🤍💙 \n#worldcup2022 #leo...  sports
# 1428   It is not a political message, it is our count...  sports
# 4286   Fuck Boudiaf! \n@EnnerValencia14 is is inviola...  sports
# 12262  Turning 30 and Unmarried Felt Like I Underachi...  sports
# ...                                                  ...     ...
# 3094   @JohnMcMah0n Thanks for your #WorldCup2022 #Re...  sports
# 19     @ALosersLament @Majstar7 @piersmorgan racist u...  sports
# 10012  Plot Twist: The refs were the ones really paid...  sports
# 2220   The Ministry announces facilities to attract f...  sports
# 16705  To all England and Wales fans traveling to the...  sports
#
# [1000 rows x 2 columns]

# %%
nba = pd.read_csv('NBA.csv')
nba.dropna(inplace=True)
nba = nba[['text']]
nba['topic'] = 'sports'
nba = nba.sample(n=1000, random_state=1)

# %%
nba
# Out:
#                                                     text   topic
# 4546      it's a wrap! #DenverNuggets  #NBAWesternFinals  sports
# 5860   #BostonCeltics need to stop playing son I’m ge...  sports
# 13820  Great season, ain’t no complaints #HEATCulture...  sports
# 16767  🔥 Tyler Herro Debut RC LOT 🔥 Bid @ $16.50 👀📈📈📈...  sports
# 3679   Vibe Czech 1, 2... Buena Vibras coming soon......  sports
# ...                                                  ...     ...
# 7286   Igoudala has passed up 2 chances now, he had t...  sports
# 15208  I'm I'm I'm gonna keep it together but but wha...  sports
# 16945  On to the Next 💪🏾🏀 #miamiheat https://t.co/r2w...  sports
# 18499  Iggy Iggy can’t you see...   Sometimes your mo...  sports
# 2528   #KobeBryant died #LakeShow #LakersNation #LosA...  sports
#
# [1000 rows x 2 columns]

# %%
nfl = pd.read_csv('NFL.csv')
nfl.dropna(inplace=True)
nfl = nfl[['text']]
nfl['topic'] = 'sports'
nfl = nfl.sample(n=1000, random_state=1)

# %%
nfl
# Out:
#                                                     text   topic
# 13830  Yeah if we had picked Fulton instead Id be thr...  sports
# 18025  So you would rather have Troy Dye? Hall couldv...  sports
# 69758                   KJ please and this is an A draft  sports
# 84305              Yall got anymore of them LBs?  Giants  sports
# 21698  For real. If we get 2 or 3 long starters thats...  sports
# ...                                                  ...     ...
# 94383  Every GM in the league would take 78 2nd round...  sports
# 69898  I really want every WR we picked in this draft...  sports
# 88073  You are not wrong and I totally agree with you...  sports
# 23047  Considering how rare it is for a team with an ...  sports
# 27676  Whats the deal with Gabe why do people think w...  sports
#
# [1000 rows x 2 columns]

# %% [markdown]
# Total number of sport related text is 3000, so we need 3000 for movie and 3000 for books...

# %%
movies_df = pd.read_csv('Movies3.csv')
movies_df = movies_df[['text']]
movies_df.dropna(inplace=True)
movies_df['topic'] = 'movie'
movies = movies_df.sample(n=3000, random_state=1)

# %%
movies
# Out:
#                                                       text  topic
# 98387    They were huge with my skater group in the lat...  movie
# 1156777  What the heck  Weren t Jackie Chan  Bruce Lee ...  movie
# 570010         Thief  1981    To Live and Die in LA  1985   movie
# 451819   Live action  the Imam from the Riddick movies ...  movie
# 954418   Isn t it great  It s in my top three of Altman s   movie
# ...                                                    ...    ...
# 325355   Hey Mr Balfe  first of all a big giant thank y...  movie
# 568285   Map of Tiny Perfect Things is my favorite  Rea...  movie
# 1490155  Meh  They are rich and insured  They ll be fin...  movie
# 2279316  shrek from the movie shrek  also rowley from t...  movie
# 1032853              In The Big Chill he was a dead cowboy  movie
#
# [3000 rows x 2 columns]

# %%
books_df = pd.read_csv('Books_rating.csv')
books_df.dropna(inplace=True)
books_df = books_df[['review/text']]
books_df.rename(columns={'review/text': 'text'}, inplace=True)
books_df['topic'] = 'book'
books = books_df.sample(n=3000, random_state=1)

# %%
books
# Out:
#                                                       text topic
# 1898915  This is an great topical reference, I use it q...  book
# 286070   I re-read this book every year at the start of...  book
# 885833   I don't know how I stumbled on this book but I...  book
# 2075898  I was very disappointed in this book. The plot...  book
# 2821735  Beautiufl coloring book. I bought these for my...  book
# ...                                                    ...   ...
# 1694666  This book was a joy to read! It shows how rewa...  book
# 2957488  While I'm sure wrestling fans will be enthrall...  book
# 2133252  My book arrived in perfect shape and in a spee...  book
# 131723   Christopher Phillips, in the true tradition es...  book
# 1593746  I wished for more from Collins' book, Communit...  book
#
# [3000 rows x 2 columns]

# %%
# Concatenating all the df's into one...
df = pd.concat([fifa,movies,nba,nfl,books], ignore_index=True)

# %%
df
# Out:
#                                                    text   topic
# 0     a fan chant jsjzhdhd #Dreamers2022 #WorldCup20...  sports
# 1     Argentina since day 1🇦🇷🤍💙 \n#worldcup2022 #leo...  sports
# 2     It is not a political message, it is our count...  sports
# 3     Fuck Boudiaf! \n@EnnerValencia14 is is inviola...  sports
# 4     Turning 30 and Unmarried Felt Like I Underachi...  sports
# ...                                                 ...     ...
# 8995  This book was a joy to read! It shows how rewa...    book
# 8996  While I'm sure wrestling fans will be enthrall...    book
# 8997  My book arrived in perfect shape and in a spee...    book
# 8998  Christopher Phillips, in the true tradition es...    book
# 8999  I wished for more from Collins' book, Communit...    book
#
# [9000 rows x 2 columns]

# %% [markdown]
# # BERT (Sentiment)

# %%
analyzer = SentimentIntensityAnalyzer()

df['text_cleaned'] = df['text'].str.lower()
df['score'] = df['text_cleaned'].apply(lambda review: analyzer.polarity_scores(review))
df['compound'] = df['text_cleaned'].apply(lambda review: analyzer.polarity_scores(review.lower())['compound'])
df['Sentiment'] = df['compound'].apply(lambda x: 'positive' if x >= 0.05 else 'negative' if x < -0.05 else 'neutral')

# %%
df
# Out:
#                                                    text   topic  \
# 0     a fan chant jsjzhdhd #Dreamers2022 #WorldCup20...  sports
# 1     Argentina since day 1🇦🇷🤍💙 \n#worldcup2022 #leo...  sports
# 2     It is not a political message, it is our count...  sports
# 3     Fuck Boudiaf! \n@EnnerValencia14 is is inviola...  sports
# 4     Turning 30 and Unmarried Felt Like I Underachi...  sports
# ...                                                 ...     ...
# 8995  This book was a joy to read! It shows how rewa...    book
# 8996  While I'm sure wrestling fans will be enthrall...    book
# 8997  My book arrived in perfect shape and in a spee...    book
# 8998  Christopher Phillips, in the true tradition es...    book
# 8999  I wished for more from Collins' book, Communit...    book
#
#                                            text_cleaned  \
# 0     a fan chant jsjzhdhd #dreamers2022 #worldcup20...
# 1     argentina since day 1🇦🇷🤍💙 \n#worldcup2022 #leo...
# 2     it is not a political message, it is our count...
# 3     fuck boudiaf! \n@ennervalencia14 is is inviola...
# 4     turning 30 and unmarried felt like i underachi...
# ...                                                 ...
# 8995  this book was a joy to read! it shows how rewa...
# 8996  while i'm sure wrestling fans will be enthrall...
# 8997  my book arrived in perfect shape and in a spee...
# 8998  christopher phillips, in the true tradition es...
# 8999  i wished for more from collins' book, communit...
#
#                                                   score  compound Sentiment
# 0     {'neg': 0.0, 'neu': 0.723, 'pos': 0.277, 'comp...    0.3182  positive
# 1     {'neg': 0.0, 'neu': 0.756, 'pos': 0.244, 'comp...    0.6369  positive
# 2     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000   neutral
# 3     {'neg': 0.387, 'neu': 0.613, 'pos': 0.0, 'comp...   -0.5848  negative
# 4     {'neg': 0.0, 'neu': 0.82, 'pos': 0.18, 'compou...    0.6908  positive
# ...                                                 ...       ...       ...
# 8995  {'neg': 0.016, 'neu': 0.728, 'pos': 0.256, 'co...    0.9894  positive
# 8996  {'neg': 0.15, 'neu': 0.674, 'pos': 0.175, 'com...    0.5939  positive
# 8997  {'neg': 0.0, 'neu': 0.699, 'pos': 0.301, 'comp...    0.7841  positive
# 8998  {'neg': 0.0, 'neu': 0.807, 'pos': 0.193, 'comp...    0.7845  positive
# 8999  {'neg': 0.025, 'neu': 0.897, 'pos': 0.077, 'co...    0.7876  positive
#
# [9000 rows x 6 columns]

# %%
value_counts = df['Sentiment'].value_counts()
print("Occurrences of each distinct value in the column:")
print(value_counts)
# Out:
# Occurrences of each distinct value in the column:
# Sentiment
# positive    5375
# negative    1833
# neutral     1792
# Name: count, dtype: int64

# %%
mapping = {'negative': 0, 'positive': 1, 'neutral': 2}
for index, row in df.iterrows():
    if row['Sentiment'] in mapping:
        df.at[index, 'Sentiment_Index'] = int(mapping[row['Sentiment']])

# %%
df
# Out:
#                                                    text   topic  \
# 0     a fan chant jsjzhdhd #Dreamers2022 #WorldCup20...  sports
# 1     Argentina since day 1🇦🇷🤍💙 \n#worldcup2022 #leo...  sports
# 2     It is not a political message, it is our count...  sports
# 3     Fuck Boudiaf! \n@EnnerValencia14 is is inviola...  sports
# 4     Turning 30 and Unmarried Felt Like I Underachi...  sports
# ...                                                 ...     ...
# 8995  This book was a joy to read! It shows how rewa...    book
# 8996  While I'm sure wrestling fans will be enthrall...    book
# 8997  My book arrived in perfect shape and in a spee...    book
# 8998  Christopher Phillips, in the true tradition es...    book
# 8999  I wished for more from Collins' book, Communit...    book
#
#                                            text_cleaned  \
# 0     a fan chant jsjzhdhd #dreamers2022 #worldcup20...
# 1     argentina since day 1🇦🇷🤍💙 \n#worldcup2022 #leo...
# 2     it is not a political message, it is our count...
# 3     fuck boudiaf! \n@ennervalencia14 is is inviola...
# 4     turning 30 and unmarried felt like i underachi...
# ...                                                 ...
# 8995  this book was a joy to read! it shows how rewa...
# 8996  while i'm sure wrestling fans will be enthrall...
# 8997  my book arrived in perfect shape and in a spee...
# 8998  christopher phillips, in the true tradition es...
# 8999  i wished for more from collins' book, communit...
#
#                                                   score  compound Sentiment  \
# 0     {'neg': 0.0, 'neu': 0.723, 'pos': 0.277, 'comp...    0.3182  positive
# 1     {'neg': 0.0, 'neu': 0.756, 'pos': 0.244, 'comp...    0.6369  positive
# 2     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000   neutral
# 3     {'neg': 0.387, 'neu': 0.613, 'pos': 0.0, 'comp...   -0.5848  negative
# 4     {'neg': 0.0, 'neu': 0.82, 'pos': 0.18, 'compou...    0.6908  positive
# ...                                                 ...       ...       ...
# 8995  {'neg': 0.016, 'neu': 0.728, 'pos': 0.256, 'co...    0.9894  positive
# 8996  {'neg': 0.15, 'neu': 0.674, 'pos': 0.175, 'com...    0.5939  positive
# 8997  {'neg': 0.0, 'neu': 0.699, 'pos': 0.301, 'comp...    0.7841  positive
# 8998  {'neg': 0.0, 'neu': 0.807, 'pos': 0.193, 'comp...    0.7845  positive
# 8999  {'neg': 0.025, 'neu': 0.897, 'pos': 0.077, 'co...    0.7876  positive
#
#       Sentiment_Index
# 0                 1.0
# 1                 1.0
# 2                 2.0
# 3                 0.0
# 4                 1.0
# ...               ...
# 8995              1.0
# 8996              1.0
# 8997              1.0
# 8998              1.0
# 8999              1.0
#
# [9000 rows x 7 columns]

# %%
sentiment_groups = [df[df['Sentiment_Index'] == sentiment] for sentiment in [0, 1, 2]]

# %%
balanced_groups = [group.sample(n=1750) for group in sentiment_groups]

# %%
balanced_groups
# Out:
# [                                                   text   topic  \
#  2280  Sloth was an establish criminal  notice how th...   movie
#  51    Now that the Qatar World Cup has begun, I take...  sports
#  230              What the hell!!! #rigged #WorldCup2022  sports
#  5641  idk Veach pulled salary cap out of his asshole...  sports
#  8961  Tremendously comprehensive. Having been a vege...    book
#  ...                                                 ...     ...
#  2196                                         Star Wars    movie
#  6363  Do not waste your money on this book! I was ve...    book
#  1405  Taps was the movie that helped make Tom Cruise...   movie
#  1876         I think worse is Depp and Marion Cotillard   movie
#  3530  Yep  and what d we get for all of that waiting...   movie
#
#                                             text_cleaned  \
#  2280  sloth was an establish criminal  notice how th...
#  51    now that the qatar world cup has begun, i take...
#  230              what the hell!!! #rigged #worldcup2022
#  5641  idk veach pulled salary cap out of his asshole...
#  8961  tremendously comprehensive. having been a vege...
#  ...                                                 ...
#  2196                                         star wars
#  6363  do not waste your money on this book! i was ve...
#  1405  taps was the movie that helped make tom cruise...
#  1876         i think worse is depp and marion cotillard
#  3530  yep  and what d we get for all of that waiting...
#
#                                                    score  compound Sentiment  \
#  2280  {'neg': 0.111, 'neu': 0.812, 'pos': 0.077, 'co...   -0.4946  negative
#  51    {'neg': 0.088, 'neu': 0.912, 'pos': 0.0, 'comp...   -0.4404  negative
#  230   {'neg': 0.727, 'neu': 0.273, 'pos': 0.0, 'comp...   -0.8392  negative
#  5641  {'neg': 0.08, 'neu': 0.92, 'pos': 0.0, 'compou...   -0.1027  negative
#  8961  {'neg': 0.097, 'neu': 0.817, 'pos': 0.086, 'co...   -0.6324  negative
#  ...                                                 ...       ...       ...
#  2196  {'neg': 0.783, 'neu': 0.217, 'pos': 0.0, 'comp...   -0.5574  negative
#  6363  {'neg': 0.145, 'neu': 0.833, 'pos': 0.022, 'co...   -0.9068  negative
#  1405  {'neg': 0.049, 'neu': 0.951, 'pos': 0.0, 'comp...   -0.2057  negative
#  1876  {'neg': 0.307, 'neu': 0.693, 'pos': 0.0, 'comp...   -0.4767  negative
#  3530  {'neg': 0.118, 'neu': 0.786, 'pos': 0.096, 'co...   -0.1280  negative
#
#        Sentiment_Index
#  2280              0.0
#  51                0.0
#  230               0.0
#  5641              0.0
#  8961              0.0
#  ...               ...
#  2196              0.0
#  6363              0.0
#  1405              0.0
#  1876              0.0
#  3530              0.0
#
#  [1750 rows x 7 columns],
#                                                     text   topic  \
#  4656  Well, even if @MiamiHEAT is my team, I'm still...  sports
#  4789                   Well it's game 4! #BostonCeltics  sports
#  5458  Ive been saying it for a while, idk about need...  sports
#  6956  In the midst of my own struggle with infertili...    book
#  1104  It s tragic what happened to Mel Gibson becaus...   movie
#  ...                                                 ...     ...
#  1388                                          For sure    movie
#  1034  Surprised they portrayed him as a bottom while...   movie
#  8930  In "If Nobody Speaks of Remarkable Things," Jo...    book
#  7278  Most Roman reference books seem to present the...    book
#  2264  Its still pretty good wine  especially for the...   movie
#
#                                             text_cleaned  \
#  4656  well, even if @miamiheat is my team, i'm still...
#  4789                   well it's game 4! #bostonceltics
#  5458  ive been saying it for a while, idk about need...
#  6956  in the midst of my own struggle with infertili...
#  1104  it s tragic what happened to mel gibson becaus...
#  ...                                                 ...
#  1388                                          for sure
#  1034  surprised they portrayed him as a bottom while...
#  8930  in "if nobody speaks of remarkable things," jo...
#  7278  most roman reference books seem to present the...
#  2264  its still pretty good wine  especially for the...
#
#                                                    score  compound Sentiment  \
#  4656  {'neg': 0.068, 'neu': 0.567, 'pos': 0.365, 'co...    0.9201  positive
#  4789  {'neg': 0.0, 'neu': 0.626, 'pos': 0.374, 'comp...    0.3382  positive
#  5458  {'neg': 0.046, 'neu': 0.762, 'pos': 0.192, 'co...    0.7050  positive
#  6956  {'neg': 0.06, 'neu': 0.725, 'pos': 0.215, 'com...    0.9923  positive
#  1104  {'neg': 0.184, 'neu': 0.613, 'pos': 0.202, 'co...    0.0772  positive
#  ...                                                 ...       ...       ...
#  1388  {'neg': 0.0, 'neu': 0.303, 'pos': 0.697, 'comp...    0.3182  positive
#  1034  {'neg': 0.0, 'neu': 0.756, 'pos': 0.244, 'comp...    0.5423  positive
#  8930  {'neg': 0.067, 'neu': 0.77, 'pos': 0.163, 'com...    0.9899  positive
#  7278  {'neg': 0.0, 'neu': 0.921, 'pos': 0.079, 'comp...    0.7425  positive
#  2264  {'neg': 0.0, 'neu': 0.71, 'pos': 0.29, 'compou...    0.9337  positive
#
#        Sentiment_Index
#  4656              1.0
#  4789              1.0
#  5458              1.0
#  6956              1.0
#  1104              1.0
#  ...               ...
#  1388              1.0
#  1034              1.0
#  8930              1.0
#  7278              1.0
#  2264              1.0
#
#  [1750 rows x 7 columns],
#                                                     text   topic  \
#  8026  This book is an absolute must for new teachers...    book
#  1268                      They also switched out Sonja    movie
#  224   @TopGoal_NFT @BNBCHAIN lettts gooo\n@RamDarman...  sports
#  2081  Father of the Bride Part III  I know there s a...   movie
#  4268  #CharlotteHornets 9 card lot $12 shipped #bask...  sports
#  ...                                                 ...     ...
#  1111                          He s gonna lay some cable   movie
#  5007               He just needs to hold onto the ball.  sports
#  2922                              RETAAIINER  Retainer    movie
#  4041  Was it though?🤔👇🏽 #backsportspage #brooklynnet...  sports
#  5385                        This is the correct answer.  sports
#
#                                             text_cleaned  \
#  8026  this book is an absolute must for new teachers...
#  1268                      they also switched out sonja
#  224   @topgoal_nft @bnbchain lettts gooo\n@ramdarman...
#  2081  father of the bride part iii  i know there s a...
#  4268  #charlottehornets 9 card lot $12 shipped #bask...
#  ...                                                 ...
#  1111                          he s gonna lay some cable
#  5007               he just needs to hold onto the ball.
#  2922                              retaaiiner  retainer
#  4041  was it though?🤔👇🏽 #backsportspage #brooklynnet...
#  5385                        this is the correct answer.
#
#                                                    score  compound Sentiment  \
#  8026  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.0   neutral
#  1268  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.0   neutral
#  224   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.0   neutral
#  2081  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.0   neutral
#  4268  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.0   neutral
#  ...                                                 ...       ...       ...
#  1111  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.0   neutral
#  5007  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.0   neutral
#  2922  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.0   neutral
#  4041  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.0   neutral
#  5385  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.0   neutral
#
#        Sentiment_Index
#  8026              2.0
#  1268              2.0
#  224               2.0
#  2081              2.0
#  4268              2.0
#  ...               ...
#  1111              2.0
#  5007              2.0
#  2922              2.0
#  4041              2.0
#  5385              2.0
#
#  [1750 rows x 7 columns]]

# %%
df
# Out:
#                                                    text   topic  \
# 0     a fan chant jsjzhdhd #Dreamers2022 #WorldCup20...  sports
# 1     Argentina since day 1🇦🇷🤍💙 \n#worldcup2022 #leo...  sports
# 2     It is not a political message, it is our count...  sports
# 3     Fuck Boudiaf! \n@EnnerValencia14 is is inviola...  sports
# 4     Turning 30 and Unmarried Felt Like I Underachi...  sports
# ...                                                 ...     ...
# 8995  This book was a joy to read! It shows how rewa...    book
# 8996  While I'm sure wrestling fans will be enthrall...    book
# 8997  My book arrived in perfect shape and in a spee...    book
# 8998  Christopher Phillips, in the true tradition es...    book
# 8999  I wished for more from Collins' book, Communit...    book
#
#                                            text_cleaned  \
# 0     a fan chant jsjzhdhd #dreamers2022 #worldcup20...
# 1     argentina since day 1🇦🇷🤍💙 \n#worldcup2022 #leo...
# 2     it is not a political message, it is our count...
# 3     fuck boudiaf! \n@ennervalencia14 is is inviola...
# 4     turning 30 and unmarried felt like i underachi...
# ...                                                 ...
# 8995  this book was a joy to read! it shows how rewa...
# 8996  while i'm sure wrestling fans will be enthrall...
# 8997  my book arrived in perfect shape and in a spee...
# 8998  christopher phillips, in the true tradition es...
# 8999  i wished for more from collins' book, communit...
#
#                                                   score  compound Sentiment  \
# 0     {'neg': 0.0, 'neu': 0.723, 'pos': 0.277, 'comp...    0.3182  positive
# 1     {'neg': 0.0, 'neu': 0.756, 'pos': 0.244, 'comp...    0.6369  positive
# 2     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000   neutral
# 3     {'neg': 0.387, 'neu': 0.613, 'pos': 0.0, 'comp...   -0.5848  negative
# 4     {'neg': 0.0, 'neu': 0.82, 'pos': 0.18, 'compou...    0.6908  positive
# ...                                                 ...       ...       ...
# 8995  {'neg': 0.016, 'neu': 0.728, 'pos': 0.256, 'co...    0.9894  positive
# 8996  {'neg': 0.15, 'neu': 0.674, 'pos': 0.175, 'com...    0.5939  positive
# 8997  {'neg': 0.0, 'neu': 0.699, 'pos': 0.301, 'comp...    0.7841  positive
# 8998  {'neg': 0.0, 'neu': 0.807, 'pos': 0.193, 'comp...    0.7845  positive
# 8999  {'neg': 0.025, 'neu': 0.897, 'pos': 0.077, 'co...    0.7876  positive
#
#       Sentiment_Index
# 0                 1.0
# 1                 1.0
# 2                 2.0
# 3                 0.0
# 4                 1.0
# ...               ...
# 8995              1.0
# 8996              1.0
# 8997              1.0
# 8998              1.0
# 8999              1.0
#
# [9000 rows x 7 columns]

# %%
balanced_df = pd.concat(balanced_groups)

# %%
balanced_df
# Out:
#                                                    text   topic  \
# 2280  Sloth was an establish criminal  notice how th...   movie
# 51    Now that the Qatar World Cup has begun, I take...  sports
# 230              What the hell!!! #rigged #WorldCup2022  sports
# 5641  idk Veach pulled salary cap out of his asshole...  sports
# 8961  Tremendously comprehensive. Having been a vege...    book
# ...                                                 ...     ...
# 1111                          He s gonna lay some cable   movie
# 5007               He just needs to hold onto the ball.  sports
# 2922                              RETAAIINER  Retainer    movie
# 4041  Was it though?🤔👇🏽 #backsportspage #brooklynnet...  sports
# 5385                        This is the correct answer.  sports
#
#                                            text_cleaned  \
# 2280  sloth was an establish criminal  notice how th...
# 51    now that the qatar world cup has begun, i take...
# 230              what the hell!!! #rigged #worldcup2022
# 5641  idk veach pulled salary cap out of his asshole...
# 8961  tremendously comprehensive. having been a vege...
# ...                                                 ...
# 1111                          he s gonna lay some cable
# 5007               he just needs to hold onto the ball.
# 2922                              retaaiiner  retainer
# 4041  was it though?🤔👇🏽 #backsportspage #brooklynnet...
# 5385                        this is the correct answer.
#
#                                                   score  compound Sentiment  \
# 2280  {'neg': 0.111, 'neu': 0.812, 'pos': 0.077, 'co...   -0.4946  negative
# 51    {'neg': 0.088, 'neu': 0.912, 'pos': 0.0, 'comp...   -0.4404  negative
# 230   {'neg': 0.727, 'neu': 0.273, 'pos': 0.0, 'comp...   -0.8392  negative
# 5641  {'neg': 0.08, 'neu': 0.92, 'pos': 0.0, 'compou...   -0.1027  negative
# 8961  {'neg': 0.097, 'neu': 0.817, 'pos': 0.086, 'co...   -0.6324  negative
# ...                                                 ...       ...       ...
# 1111  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000   neutral
# 5007  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000   neutral
# 2922  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000   neutral
# 4041  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000   neutral
# 5385  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000   neutral
#
#       Sentiment_Index
# 2280              0.0
# 51                0.0
# 230               0.0
# 5641              0.0
# 8961              0.0
# ...               ...
# 1111              2.0
# 5007              2.0
# 2922              2.0
# 4041              2.0
# 5385              2.0
#
# [5250 rows x 7 columns]

# %%
df = balanced_df.sample(frac=1).reset_index(drop=True)

# %%
df
# Out:
#                                                    text   topic  \
# 0     As a Pastor,this book is so good I give a copy...    book
# 1                       Mmm  that is one tasty burger     movie
# 2     Official Poster for  Ruby Gillman  Teenage Kra...   movie
# 3                            Wtf are you talking about    movie
# 4                He s talking about a retired investor    movie
# ...                                                 ...     ...
# 5245  Good book but I don't recommended it for no on...    book
# 5246   How was the first match at Qatar #WorldCup2022 ?  sports
# 5247  I am a rape survivor and yes, it can lead to T...    book
# 5248  Spoilers for Peacemaker   I always thought it ...   movie
# 5249  For Kobe #Kobethisisforyou #LosAngelesLakers h...  sports
#
#                                            text_cleaned  \
# 0     as a pastor,this book is so good i give a copy...
# 1                       mmm  that is one tasty burger
# 2     official poster for  ruby gillman  teenage kra...
# 3                            wtf are you talking about
# 4                he s talking about a retired investor
# ...                                                 ...
# 5245  good book but i don't recommended it for no on...
# 5246   how was the first match at qatar #worldcup2022 ?
# 5247  i am a rape survivor and yes, it can lead to t...
# 5248  spoilers for peacemaker   i always thought it ...
# 5249  for kobe #kobethisisforyou #losangeleslakers h...
#
#                                                   score  compound Sentiment  \
# 0     {'neg': 0.0, 'neu': 0.87, 'pos': 0.13, 'compou...    0.6826  positive
# 1     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000   neutral
# 2     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000   neutral
# 3     {'neg': 0.487, 'neu': 0.513, 'pos': 0.0, 'comp...   -0.5859  negative
# 4     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000   neutral
# ...                                                 ...       ...       ...
# 5245  {'neg': 0.094, 'neu': 0.866, 'pos': 0.039, 'co...   -0.4094  negative
# 5246  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000   neutral
# 5247  {'neg': 0.31, 'neu': 0.548, 'pos': 0.142, 'com...   -0.9199  negative
# 5248  {'neg': 0.02, 'neu': 0.805, 'pos': 0.175, 'com...    0.9509  positive
# 5249  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000   neutral
#
#       Sentiment_Index
# 0                 1.0
# 1                 2.0
# 2                 2.0
# 3                 0.0
# 4                 2.0
# ...               ...
# 5245              0.0
# 5246              2.0
# 5247              0.0
# 5248              1.0
# 5249              2.0
#
# [5250 rows x 7 columns]

# %%
df1 = pd.DataFrame(columns=['data', 'target'])

df1['data'] = df['text_cleaned']
df1['target'] = df['Sentiment_Index']


categories = ['positive', 'neutral', 'negative']
train_set_S = df1.sample(frac=0.8, random_state=1)
test_set_S = df1.drop(train_set_S.index)

train_set_S

train = pd.DataFrame({'text': train_set_S.data, 'target': train_set_S.target})

test = pd.DataFrame({'text': test_set_S.data, 'target': test_set_S.target})


train, dev = train_test_split(train, test_size=0.15, random_state=1, 
                               stratify=train[['target']])

# Model configuration # https://simpletransformers.ai/docs/usage/#configuring-a-simple-transformers-model 
model_args = ClassificationArgs()

model_args.overwrite_output_dir=True # overwrite existing saved models in the same directory
model_args.evaluate_during_training=True # to perform evaluation while training the model
# (eval data should be passed to the training method)

model_args.num_train_epochs=10 # number of epochs
model_args.train_batch_size=32 # batch size
model_args.learning_rate=4e-6 # learning rate
model_args.max_seq_length=256 # maximum sequence length
# Note! Increasing max_seq_len may provide better performance, but training time will increase. 
# For educational purposes, we set max_seq_len to 256.

# Early stopping to combat overfitting: https://simpletransformers.ai/docs/tips-and-tricks/#using-early-stopping
model_args.use_early_stopping=True
model_args.early_stopping_delta=0.01 # "The improvement over best_eval_loss necessary to count as a better checkpoint"
model_args.early_stopping_metric='eval_loss'
model_args.early_stopping_metric_minimize=True
model_args.early_stopping_patience=2
model_args.evaluate_during_training_steps=32 # how often you want to run validation in terms of training steps (or batches)

# Checking steps per epoch
steps_per_epoch = int(np.ceil(len(train) / float(model_args.train_batch_size)))
print('Each epoch will have {:,} steps.'.format(steps_per_epoch)) # 64 steps = validating 2 times per epoch

model = ClassificationModel('bert', 'bert-base-cased', num_labels=3, args=model_args, use_cuda=True) # CUDA is enabled

_, history = model.train_model(train, eval_df=dev)
# Out:
# Each epoch will have 112 steps.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# C:\Users\Precision5570\anaconda3\envs\TextMining5\Lib\site-packages\simpletransformers\classification\classification_model.py:608: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   warnings.warn(
# 8it [00:23,  2.99s/it]
# Epoch 1 of 10:   0%|          | 0/10 [00:00<?, ?it/s]
# Running Epoch 1 of 10:   0%|          | 0/112 [00:00<?, ?it/s]
# Epochs 1/10. Running Loss:    1.2009:   0%|          | 0/112 [00:08<?, ?it/s]
# Epochs 1/10. Running Loss:    1.2009:   1%|          | 1/112 [00:09<17:32,  9.48s/it]
# Epochs 1/10. Running Loss:    1.1969:   1%|          | 1/112 [00:13<17:32,  9.48s/it]
# Epochs 1/10. Running Loss:    1.1969:   2%|▏         | 2/112 [00:16<14:13,  7.76s/it]
# Epochs 1/10. Running Loss:    1.1436:   2%|▏         | 2/112 [00:16<14:13,  7.76s/it]
# Epochs 1/10. Running Loss:    1.1436:   3%|▎         | 3/112 [00:18<09:55,  5.46s/it]
# Epochs 1/10. Running Loss:    1.1239:   3%|▎         | 3/112 [00:19<09:55,  5.46s/it]
# Epochs 1/10. Running Loss:    1.1239:   4%|▎         | 4/112 [00:21<07:53,  4.38s/it]
# Epochs 1/10. Running Loss:    1.3030:   4%|▎         | 4/112 [00:22<07:53,  4.38s/it]
# Epochs 1/10. Running Loss:    1.3030:   4%|▍         | 5/112 [00:24<06:44,  3.78s/it]
# Epochs 1/10. Running Loss:    1.1844:   4%|▍         | 5/112 [00:25<06:44,  3.78s/it]
# Epochs 1/10. Running Loss:    1.1844:   5%|▌         | 6/112 [00:26<06:01,  3.41s/it]
# Epochs 1/10. Running Loss:    1.2071:   5%|▌         | 6/112 [00:27<06:01,  3.41s/it]
# Epochs 1/10. Running Loss:    1.2071:   6%|▋         | 7/112 [00:29<05:34,  3.19s/it]
# Epochs 1/10. Running Loss:    1.0873:   6%|▋         | 7/112 [00:30<05:34,  3.19s/it]
# Epochs 1/10. Running Loss:    1.0873:   7%|▋         | 8/112 [00:32<05:16,  3.04s/it]
# Epochs 1/10. Running Loss:    1.1763:   7%|▋         | 8/112 [00:33<05:16,  3.04s/it]
# Epochs 1/10. Running Loss:    1.1763:   8%|▊         | 9/112 [00:35<05:04,  2.96s/it]
# Epochs 1/10. Running Loss:    1.1682:   8%|▊         | 9/112 [00:36<05:04,  2.96s/it]
# Epochs 1/10. Running Loss:    1.1682:   9%|▉         | 10/112 [00:37<04:57,  2.91s/it]
# Epochs 1/10. Running Loss:    1.0676:   9%|▉         | 10/112 [00:38<04:57,  2.91s/it]
# Epochs 1/10. Running Loss:    1.0676:  10%|▉         | 11/112 [00:40<04:47,  2.84s/it]
# Epochs 1/10. Running Loss:    1.0839:  10%|▉         | 11/112 [00:41<04:47,  2.84s/it]
# Epochs 1/10. Running Loss:    1.0839:  11%|█         | 12/112 [00:43<04:38,  2.79s/it]
# Epochs 1/10. Running Loss:    1.1582:  11%|█         | 12/112 [00:44<04:38,  2.79s/it]
# Epochs 1/10. Running Loss:    1.1582:  12%|█▏        | 13/112 [00:45<04:33,  2.76s/it]
# Epochs 1/10. Running Loss:    1.2314:  12%|█▏        | 13/112 [00:46<04:33,  2.76s/it]
# Epochs 1/10. Running Loss:    1.2314:  12%|█▎        | 14/112 [00:48<04:27,  2.73s/it]
# Epochs 1/10. Running Loss:    1.1031:  12%|█▎        | 14/112 [00:49<04:27,  2.73s/it]
# Epochs 1/10. Running Loss:    1.1031:  13%|█▎        | 15/112 [00:51<04:22,  2.71s/it]
# Epochs 1/10. Running Loss:    1.1198:  13%|█▎        | 15/112 [00:52<04:22,  2.71s/it]
# Epochs 1/10. Running Loss:    1.1198:  14%|█▍        | 16/112 [00:54<04:19,  2.70s/it]
# Epochs 1/10. Running Loss:    1.0949:  14%|█▍        | 16/112 [00:54<04:19,  2.70s/it]
# Epochs 1/10. Running Loss:    1.0949:  15%|█▌        | 17/112 [00:56<04:16,  2.70s/it]
# Epochs 1/10. Running Loss:    1.2614:  15%|█▌        | 17/112 [00:57<04:16,  2.70s/it]
# Epochs 1/10. Running Loss:    1.2614:  16%|█▌        | 18/112 [00:59<04:12,  2.69s/it]
# Epochs 1/10. Running Loss:    1.2200:  16%|█▌        | 18/112 [01:00<04:12,  2.69s/it]
# Epochs 1/10. Running Loss:    1.2200:  17%|█▋        | 19/112 [01:02<04:09,  2.68s/it]
# Epochs 1/10. Running Loss:    1.1565:  17%|█▋        | 19/112 [01:02<04:09,  2.68s/it]
# Epochs 1/10. Running Loss:    1.1565:  18%|█▊        | 20/112 [01:04<04:06,  2.68s/it]
# Epochs 1/10. Running Loss:    1.1750:  18%|█▊        | 20/112 [01:05<04:06,  2.68s/it]
# Epochs 1/10. Running Loss:    1.1750:  19%|█▉        | 21/112 [01:07<04:03,  2.67s/it]
# Epochs 1/10. Running Loss:    1.1240:  19%|█▉        | 21/112 [01:08<04:03,  2.67s/it]
# Epochs 1/10. Running Loss:    1.1240:  20%|█▉        | 22/112 [01:10<04:01,  2.68s/it]
# Epochs 1/10. Running Loss:    1.1872:  20%|█▉        | 22/112 [01:10<04:01,  2.68s/it]
# Epochs 1/10. Running Loss:    1.1872:  21%|██        | 23/112 [01:12<03:58,  2.67s/it]
# Epochs 1/10. Running Loss:    1.1326:  21%|██        | 23/112 [01:13<03:58,  2.67s/it]
# Epochs 1/10. Running Loss:    1.1326:  21%|██▏       | 24/112 [01:15<03:55,  2.67s/it]
# Epochs 1/10. Running Loss:    1.1150:  21%|██▏       | 24/112 [01:16<03:55,  2.67s/it]
# Epochs 1/10. Running Loss:    1.1150:  22%|██▏       | 25/112 [01:18<03:53,  2.68s/it]
# Epochs 1/10. Running Loss:    1.0990:  22%|██▏       | 25/112 [01:19<03:53,  2.68s/it]
# Epochs 1/10. Running Loss:    1.0990:  23%|██▎       | 26/112 [01:21<03:57,  2.76s/it]
# Epochs 1/10. Running Loss:    1.1073:  23%|██▎       | 26/112 [01:21<03:57,  2.76s/it]
# Epochs 1/10. Running Loss:    1.1073:  24%|██▍       | 27/112 [01:23<03:54,  2.76s/it]
# Epochs 1/10. Running Loss:    1.2993:  24%|██▍       | 27/112 [01:24<03:54,  2.76s/it]
# Epochs 1/10. Running Loss:    1.2993:  25%|██▌       | 28/112 [01:26<03:49,  2.73s/it]
# Epochs 1/10. Running Loss:    1.0693:  25%|██▌       | 28/112 [01:27<03:49,  2.73s/it]
# Epochs 1/10. Running Loss:    1.0693:  26%|██▌       | 29/112 [01:29<03:45,  2.72s/it]
# Epochs 1/10. Running Loss:    1.1257:  26%|██▌       | 29/112 [01:30<03:45,  2.72s/it]
# Epochs 1/10. Running Loss:    1.1257:  27%|██▋       | 30/112 [01:31<03:41,  2.70s/it]
# Epochs 1/10. Running Loss:    1.1304:  27%|██▋       | 30/112 [01:32<03:41,  2.70s/it]
# Epochs 1/10. Running Loss:    1.1304:  28%|██▊       | 31/112 [01:34<03:38,  2.70s/it]
# Epochs 1/10. Running Loss:    1.1384:  28%|██▊       | 31/112 [01:35<03:38,  2.70s/it]C:\Users\Precision5570\anaconda3\envs\TextMining5\Lib\site-packages\simpletransformers\classification\classification_model.py:1452: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   warnings.warn(
#
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# 2it [00:18,  9.26s/it]
#
# Epochs 1/10. Running Loss:    1.1384:  29%|██▊       | 32/112 [02:08<16:00, 12.01s/it]
# Epochs 1/10. Running Loss:    1.0810:  29%|██▊       | 32/112 [02:09<16:00, 12.01s/it]
# Epochs 1/10. Running Loss:    1.0810:  29%|██▉       | 33/112 [02:10<11:52,  9.01s/it]
# Epochs 1/10. Running Loss:    1.0619:  29%|██▉       | 33/112 [02:10<11:52,  9.01s/it]
# Epochs 1/10. Running Loss:    1.0619:  30%|███       | 34/112 [02:11<08:52,  6.83s/it]
# Epochs 1/10. Running Loss:    1.1488:  30%|███       | 34/112 [02:12<08:52,  6.83s/it]
# Epochs 1/10. Running Loss:    1.1488:  31%|███▏      | 35/112 [02:13<06:47,  5.29s/it]
# Epochs 1/10. Running Loss:    1.1253:  31%|███▏      | 35/112 [02:14<06:47,  5.29s/it]
# Epochs 1/10. Running Loss:    1.1253:  32%|███▏      | 36/112 [02:15<05:19,  4.21s/it]
# Epochs 1/10. Running Loss:    1.1111:  32%|███▏      | 36/112 [02:16<05:19,  4.21s/it]
# Epochs 1/10. Running Loss:    1.1111:  33%|███▎      | 37/112 [02:17<04:19,  3.47s/it]
# Epochs 1/10. Running Loss:    1.1267:  33%|███▎      | 37/112 [02:17<04:19,  3.47s/it]
# Epochs 1/10. Running Loss:    1.1267:  34%|███▍      | 38/112 [02:18<03:39,  2.96s/it]
# Epochs 1/10. Running Loss:    1.0953:  34%|███▍      | 38/112 [02:19<03:39,  2.96s/it]
# Epochs 1/10. Running Loss:    1.0953:  35%|███▍      | 39/112 [02:20<03:08,  2.59s/it]
# Epochs 1/10. Running Loss:    1.1452:  35%|███▍      | 39/112 [02:21<03:08,  2.59s/it]
# Epochs 1/10. Running Loss:    1.1452:  36%|███▌      | 40/112 [02:22<02:45,  2.30s/it]
# Epochs 1/10. Running Loss:    1.0398:  36%|███▌      | 40/112 [02:22<02:45,  2.30s/it]
# Epochs 1/10. Running Loss:    1.0398:  37%|███▋      | 41/112 [02:23<02:30,  2.12s/it]
# Epochs 1/10. Running Loss:    1.1508:  37%|███▋      | 41/112 [02:24<02:30,  2.12s/it]
# Epochs 1/10. Running Loss:    1.1508:  38%|███▊      | 42/112 [02:25<02:20,  2.00s/it]
# Epochs 1/10. Running Loss:    1.0988:  38%|███▊      | 42/112 [02:26<02:20,  2.00s/it]
# Epochs 1/10. Running Loss:    1.0988:  38%|███▊      | 43/112 [02:27<02:11,  1.90s/it]
# Epochs 1/10. Running Loss:    1.0323:  38%|███▊      | 43/112 [02:27<02:11,  1.90s/it]
# Epochs 1/10. Running Loss:    1.0323:  39%|███▉      | 44/112 [02:28<02:04,  1.83s/it]
# Epochs 1/10. Running Loss:    1.0831:  39%|███▉      | 44/112 [02:29<02:04,  1.83s/it]
# Epochs 1/10. Running Loss:    1.0831:  40%|████      | 45/112 [02:30<01:59,  1.79s/it]
# Epochs 1/10. Running Loss:    1.0916:  40%|████      | 45/112 [02:31<01:59,  1.79s/it]
# Epochs 1/10. Running Loss:    1.0916:  41%|████      | 46/112 [02:32<01:55,  1.75s/it]
# Epochs 1/10. Running Loss:    1.0716:  41%|████      | 46/112 [02:32<01:55,  1.75s/it]
# Epochs 1/10. Running Loss:    1.0716:  42%|████▏     | 47/112 [02:34<01:52,  1.74s/it]
# Epochs 1/10. Running Loss:    1.0636:  42%|████▏     | 47/112 [02:34<01:52,  1.74s/it]
# Epochs 1/10. Running Loss:    1.0636:  43%|████▎     | 48/112 [02:35<01:49,  1.72s/it]
# Epochs 1/10. Running Loss:    1.0633:  43%|████▎     | 48/112 [02:36<01:49,  1.72s/it]
# Epochs 1/10. Running Loss:    1.0633:  44%|████▍     | 49/112 [02:37<01:47,  1.71s/it]
# Epochs 1/10. Running Loss:    1.0282:  44%|████▍     | 49/112 [02:38<01:47,  1.71s/it]
# Epochs 1/10. Running Loss:    1.0282:  45%|████▍     | 50/112 [02:39<01:46,  1.71s/it]
# Epochs 1/10. Running Loss:    1.0764:  45%|████▍     | 50/112 [02:39<01:46,  1.71s/it]
# Epochs 1/10. Running Loss:    1.0764:  46%|████▌     | 51/112 [02:40<01:43,  1.70s/it]
# Epochs 1/10. Running Loss:    1.0951:  46%|████▌     | 51/112 [02:41<01:43,  1.70s/it]
# Epochs 1/10. Running Loss:    1.0951:  46%|████▋     | 52/112 [02:42<01:41,  1.69s/it]
# Epochs 1/10. Running Loss:    1.0275:  46%|████▋     | 52/112 [02:43<01:41,  1.69s/it]
# Epochs 1/10. Running Loss:    1.0275:  47%|████▋     | 53/112 [02:44<01:39,  1.68s/it]
# Epochs 1/10. Running Loss:    1.0414:  47%|████▋     | 53/112 [02:44<01:39,  1.68s/it]
# Epochs 1/10. Running Loss:    1.0414:  48%|████▊     | 54/112 [02:45<01:37,  1.69s/it]
# Epochs 1/10. Running Loss:    1.0913:  48%|████▊     | 54/112 [02:46<01:37,  1.69s/it]
# Epochs 1/10. Running Loss:    1.0913:  49%|████▉     | 55/112 [02:47<01:35,  1.68s/it]
# Epochs 1/10. Running Loss:    1.0361:  49%|████▉     | 55/112 [02:48<01:35,  1.68s/it]
# Epochs 1/10. Running Loss:    1.0361:  50%|█████     | 56/112 [02:49<01:34,  1.69s/it]
# Epochs 1/10. Running Loss:    1.0463:  50%|█████     | 56/112 [02:49<01:34,  1.69s/it]
# Epochs 1/10. Running Loss:    1.0463:  51%|█████     | 57/112 [02:50<01:32,  1.68s/it]
# Epochs 1/10. Running Loss:    1.0677:  51%|█████     | 57/112 [02:51<01:32,  1.68s/it]
# Epochs 1/10. Running Loss:    1.0677:  52%|█████▏    | 58/112 [02:52<01:30,  1.67s/it]
# Epochs 1/10. Running Loss:    1.0538:  52%|█████▏    | 58/112 [02:53<01:30,  1.67s/it]
# Epochs 1/10. Running Loss:    1.0538:  53%|█████▎    | 59/112 [02:54<01:28,  1.68s/it]
# Epochs 1/10. Running Loss:    1.0534:  53%|█████▎    | 59/112 [02:54<01:28,  1.68s/it]
# Epochs 1/10. Running Loss:    1.0534:  54%|█████▎    | 60/112 [02:55<01:26,  1.67s/it]
# Epochs 1/10. Running Loss:    1.0713:  54%|█████▎    | 60/112 [02:56<01:26,  1.67s/it]
# Epochs 1/10. Running Loss:    1.0713:  54%|█████▍    | 61/112 [02:57<01:24,  1.67s/it]
# Epochs 1/10. Running Loss:    1.0372:  54%|█████▍    | 61/112 [02:58<01:24,  1.67s/it]
# Epochs 1/10. Running Loss:    1.0372:  55%|█████▌    | 62/112 [02:59<01:24,  1.68s/it]
# Epochs 1/10. Running Loss:    1.0434:  55%|█████▌    | 62/112 [02:59<01:24,  1.68s/it]
# Epochs 1/10. Running Loss:    1.0434:  56%|█████▋    | 63/112 [03:00<01:22,  1.68s/it]
# Epochs 1/10. Running Loss:    1.0214:  56%|█████▋    | 63/112 [03:01<01:22,  1.68s/it]C:\Users\Precision5570\anaconda3\envs\TextMining5\Lib\site-packages\simpletransformers\classification\classification_model.py:1452: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   warnings.warn(
#
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# 2it [00:13,  6.66s/it]
#
# Epochs 1/10. Running Loss:    1.0214:  57%|█████▋    | 64/112 [03:25<06:53,  8.61s/it]
# Epochs 1/10. Running Loss:    1.0948:  57%|█████▋    | 64/112 [03:26<06:53,  8.61s/it]
# Epochs 1/10. Running Loss:    1.0948:  58%|█████▊    | 65/112 [03:27<05:08,  6.57s/it]
# Epochs 1/10. Running Loss:    1.0304:  58%|█████▊    | 65/112 [03:28<05:08,  6.57s/it]
# Epochs 1/10. Running Loss:    1.0304:  59%|█████▉    | 66/112 [03:29<03:54,  5.10s/it]
# Epochs 1/10. Running Loss:    1.0789:  59%|█████▉    | 66/112 [03:29<03:54,  5.10s/it]
# Epochs 1/10. Running Loss:    1.0789:  60%|█████▉    | 67/112 [03:30<03:03,  4.07s/it]
# Epochs 1/10. Running Loss:    1.0651:  60%|█████▉    | 67/112 [03:31<03:03,  4.07s/it]
# Epochs 1/10. Running Loss:    1.0651:  61%|██████    | 68/112 [03:32<02:27,  3.35s/it]
# Epochs 1/10. Running Loss:    1.0522:  61%|██████    | 68/112 [03:33<02:27,  3.35s/it]
# Epochs 1/10. Running Loss:    1.0522:  62%|██████▏   | 69/112 [03:34<02:02,  2.84s/it]
# Epochs 1/10. Running Loss:    1.0418:  62%|██████▏   | 69/112 [03:34<02:02,  2.84s/it]
# Epochs 1/10. Running Loss:    1.0418:  62%|██████▎   | 70/112 [03:35<01:44,  2.49s/it]
# Epochs 1/10. Running Loss:    1.0053:  62%|██████▎   | 70/112 [03:36<01:44,  2.49s/it]
# Epochs 1/10. Running Loss:    1.0053:  63%|██████▎   | 71/112 [03:37<01:31,  2.23s/it]
# Epochs 1/10. Running Loss:    0.9771:  63%|██████▎   | 71/112 [03:38<01:31,  2.23s/it]
# Epochs 1/10. Running Loss:    0.9771:  64%|██████▍   | 72/112 [03:39<01:22,  2.06s/it]
# Epochs 1/10. Running Loss:    1.0263:  64%|██████▍   | 72/112 [03:39<01:22,  2.06s/it]
# Epochs 1/10. Running Loss:    1.0263:  65%|██████▌   | 73/112 [03:40<01:16,  1.95s/it]
# Epochs 1/10. Running Loss:    1.0355:  65%|██████▌   | 73/112 [03:41<01:16,  1.95s/it]
# Epochs 1/10. Running Loss:    1.0355:  66%|██████▌   | 74/112 [03:42<01:10,  1.87s/it]
# Epochs 1/10. Running Loss:    1.0804:  66%|██████▌   | 74/112 [03:43<01:10,  1.87s/it]
# Epochs 1/10. Running Loss:    1.0804:  67%|██████▋   | 75/112 [03:44<01:07,  1.82s/it]
# Epochs 1/10. Running Loss:    1.0250:  67%|██████▋   | 75/112 [03:44<01:07,  1.82s/it]
# Epochs 1/10. Running Loss:    1.0250:  68%|██████▊   | 76/112 [03:45<01:03,  1.77s/it]
# Epochs 1/10. Running Loss:    0.9647:  68%|██████▊   | 76/112 [03:46<01:03,  1.77s/it]
# Epochs 1/10. Running Loss:    0.9647:  69%|██████▉   | 77/112 [03:47<01:01,  1.75s/it]
# Epochs 1/10. Running Loss:    1.0193:  69%|██████▉   | 77/112 [03:48<01:01,  1.75s/it]
# Epochs 1/10. Running Loss:    1.0193:  70%|██████▉   | 78/112 [03:49<00:58,  1.73s/it]
# Epochs 1/10. Running Loss:    1.0386:  70%|██████▉   | 78/112 [03:49<00:58,  1.73s/it]
# Epochs 1/10. Running Loss:    1.0386:  71%|███████   | 79/112 [03:50<00:56,  1.71s/it]
# Epochs 1/10. Running Loss:    0.9909:  71%|███████   | 79/112 [03:51<00:56,  1.71s/it]
# Epochs 1/10. Running Loss:    0.9909:  71%|███████▏  | 80/112 [03:52<00:54,  1.70s/it]
# Epochs 1/10. Running Loss:    1.0416:  71%|███████▏  | 80/112 [03:53<00:54,  1.70s/it]
# Epochs 1/10. Running Loss:    1.0416:  72%|███████▏  | 81/112 [03:54<00:52,  1.69s/it]
# Epochs 1/10. Running Loss:    0.9876:  72%|███████▏  | 81/112 [03:54<00:52,  1.69s/it]
# Epochs 1/10. Running Loss:    0.9876:  73%|███████▎  | 82/112 [03:55<00:50,  1.69s/it]
# Epochs 1/10. Running Loss:    1.0128:  73%|███████▎  | 82/112 [03:56<00:50,  1.69s/it]
# Epochs 1/10. Running Loss:    1.0128:  74%|███████▍  | 83/112 [03:57<00:49,  1.72s/it]
# Epochs 1/10. Running Loss:    0.9926:  74%|███████▍  | 83/112 [03:58<00:49,  1.72s/it]
# Epochs 1/10. Running Loss:    0.9926:  75%|███████▌  | 84/112 [03:59<00:48,  1.74s/it]
# Epochs 1/10. Running Loss:    1.0078:  75%|███████▌  | 84/112 [04:00<00:48,  1.74s/it]
# Epochs 1/10. Running Loss:    1.0078:  76%|███████▌  | 85/112 [04:01<00:46,  1.73s/it]
# Epochs 1/10. Running Loss:    1.0572:  76%|███████▌  | 85/112 [04:01<00:46,  1.73s/it]
# Epochs 1/10. Running Loss:    1.0572:  77%|███████▋  | 86/112 [04:02<00:44,  1.71s/it]
# Epochs 1/10. Running Loss:    1.0279:  77%|███████▋  | 86/112 [04:03<00:44,  1.71s/it]
# Epochs 1/10. Running Loss:    1.0279:  78%|███████▊  | 87/112 [04:04<00:43,  1.74s/it]
# Epochs 1/10. Running Loss:    0.9905:  78%|███████▊  | 87/112 [04:05<00:43,  1.74s/it]
# Epochs 1/10. Running Loss:    0.9905:  79%|███████▊  | 88/112 [04:06<00:41,  1.71s/it]
# Epochs 1/10. Running Loss:    1.0168:  79%|███████▊  | 88/112 [04:06<00:41,  1.71s/it]
# Epochs 1/10. Running Loss:    1.0168:  79%|███████▉  | 89/112 [04:08<00:39,  1.71s/it]
# Epochs 1/10. Running Loss:    1.0343:  79%|███████▉  | 89/112 [04:08<00:39,  1.71s/it]
# Epochs 1/10. Running Loss:    1.0343:  80%|████████  | 90/112 [04:09<00:38,  1.73s/it]
# Epochs 1/10. Running Loss:    0.9459:  80%|████████  | 90/112 [04:10<00:38,  1.73s/it]
# Epochs 1/10. Running Loss:    0.9459:  81%|████████▏ | 91/112 [04:11<00:36,  1.73s/it]
# Epochs 1/10. Running Loss:    0.9847:  81%|████████▏ | 91/112 [04:12<00:36,  1.73s/it]
# Epochs 1/10. Running Loss:    0.9847:  82%|████████▏ | 92/112 [04:13<00:34,  1.72s/it]
# Epochs 1/10. Running Loss:    0.9099:  82%|████████▏ | 92/112 [04:13<00:34,  1.72s/it]
# Epochs 1/10. Running Loss:    0.9099:  83%|████████▎ | 93/112 [04:14<00:32,  1.70s/it]
# Epochs 1/10. Running Loss:    1.0198:  83%|████████▎ | 93/112 [04:15<00:32,  1.70s/it]
# Epochs 1/10. Running Loss:    1.0198:  84%|████████▍ | 94/112 [04:16<00:31,  1.72s/it]
# Epochs 1/10. Running Loss:    0.9406:  84%|████████▍ | 94/112 [04:17<00:31,  1.72s/it]
# Epochs 1/10. Running Loss:    0.9406:  85%|████████▍ | 95/112 [04:18<00:29,  1.75s/it]
# Epochs 1/10. Running Loss:    0.9456:  85%|████████▍ | 95/112 [04:19<00:29,  1.75s/it]C:\Users\Precision5570\anaconda3\envs\TextMining5\Lib\site-packages\simpletransformers\classification\classification_model.py:1452: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   warnings.warn(
#
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# 2it [00:15,  7.91s/it]
#
# Epochs 1/10. Running Loss:    0.9456:  86%|████████▌ | 96/112 [04:44<02:22,  8.93s/it]
# Epochs 1/10. Running Loss:    0.9471:  86%|████████▌ | 96/112 [04:44<02:22,  8.93s/it]
# Epochs 1/10. Running Loss:    0.9471:  87%|████████▋ | 97/112 [04:46<01:42,  6.82s/it]
# Epochs 1/10. Running Loss:    1.0055:  87%|████████▋ | 97/112 [04:46<01:42,  6.82s/it]
# Epochs 1/10. Running Loss:    1.0055:  88%|████████▊ | 98/112 [04:47<01:13,  5.27s/it]
# Epochs 1/10. Running Loss:    0.9373:  88%|████████▊ | 98/112 [04:48<01:13,  5.27s/it]
# Epochs 1/10. Running Loss:    0.9373:  88%|████████▊ | 99/112 [04:49<00:54,  4.20s/it]
# Epochs 1/10. Running Loss:    0.9605:  88%|████████▊ | 99/112 [04:50<00:54,  4.20s/it]
# Epochs 1/10. Running Loss:    0.9605:  89%|████████▉ | 100/112 [04:51<00:41,  3.44s/it]
# Epochs 1/10. Running Loss:    0.9216:  89%|████████▉ | 100/112 [04:51<00:41,  3.44s/it]
# Epochs 1/10. Running Loss:    0.9216:  90%|█████████ | 101/112 [04:52<00:32,  2.92s/it]
# Epochs 1/10. Running Loss:    1.0181:  90%|█████████ | 101/112 [04:53<00:32,  2.92s/it]
# Epochs 1/10. Running Loss:    1.0181:  91%|█████████ | 102/112 [04:54<00:25,  2.54s/it]
# Epochs 1/10. Running Loss:    0.9591:  91%|█████████ | 102/112 [04:55<00:25,  2.54s/it]
# Epochs 1/10. Running Loss:    0.9591:  92%|█████████▏| 103/112 [04:56<00:20,  2.28s/it]
# Epochs 1/10. Running Loss:    1.0047:  92%|█████████▏| 103/112 [04:56<00:20,  2.28s/it]
# Epochs 1/10. Running Loss:    1.0047:  93%|█████████▎| 104/112 [04:57<00:16,  2.10s/it]
# Epochs 1/10. Running Loss:    1.0366:  93%|█████████▎| 104/112 [04:58<00:16,  2.10s/it]
# Epochs 1/10. Running Loss:    1.0366:  94%|█████████▍| 105/112 [04:59<00:13,  1.99s/it]
# Epochs 1/10. Running Loss:    0.9865:  94%|█████████▍| 105/112 [05:00<00:13,  1.99s/it]
# Epochs 1/10. Running Loss:    0.9865:  95%|█████████▍| 106/112 [05:01<00:11,  1.90s/it]
# Epochs 1/10. Running Loss:    0.8927:  95%|█████████▍| 106/112 [05:01<00:11,  1.90s/it]
# Epochs 1/10. Running Loss:    0.8927:  96%|█████████▌| 107/112 [05:02<00:09,  1.84s/it]
# Epochs 1/10. Running Loss:    0.9517:  96%|█████████▌| 107/112 [05:03<00:09,  1.84s/it]
# Epochs 1/10. Running Loss:    0.9517:  96%|█████████▋| 108/112 [05:04<00:07,  1.79s/it]
# Epochs 1/10. Running Loss:    0.9886:  96%|█████████▋| 108/112 [05:05<00:07,  1.79s/it]
# Epochs 1/10. Running Loss:    0.9886:  97%|█████████▋| 109/112 [05:06<00:05,  1.75s/it]
# Epochs 1/10. Running Loss:    0.9838:  97%|█████████▋| 109/112 [05:06<00:05,  1.75s/it]
# Epochs 1/10. Running Loss:    0.9838:  98%|█████████▊| 110/112 [05:07<00:03,  1.74s/it]
# Epochs 1/10. Running Loss:    0.9648:  98%|█████████▊| 110/112 [05:08<00:03,  1.74s/it]
# Epochs 1/10. Running Loss:    0.9648:  99%|█████████▉| 111/112 [05:09<00:01,  1.71s/it]
# Epochs 1/10. Running Loss:    0.8850:  99%|█████████▉| 111/112 [05:09<00:01,  1.71s/it]
# Epochs 1/10. Running Loss:    0.8850: 100%|██████████| 112/112 [05:10<00:00,  2.77s/it]
# C:\Users\Precision5570\anaconda3\envs\TextMining5\Lib\site-packages\simpletransformers\classification\classification_model.py:1452: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   warnings.warn(
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 2it [00:12,  6.32s/it]
# Epoch 2 of 10:  10%|█         | 1/10 [05:30<49:34, 330.49s/it]
# Running Epoch 2 of 10:   0%|          | 0/112 [00:00<?, ?it/s]
# Epochs 2/10. Running Loss:    0.9210:   0%|          | 0/112 [00:00<?, ?it/s]
# Epochs 2/10. Running Loss:    0.9210:   1%|          | 1/112 [00:01<03:01,  1.63s/it]
# Epochs 2/10. Running Loss:    0.9013:   1%|          | 1/112 [00:02<03:01,  1.63s/it]
# Epochs 2/10. Running Loss:    0.9013:   2%|▏         | 2/112 [00:03<03:02,  1.66s/it]
# Epochs 2/10. Running Loss:    1.0279:   2%|▏         | 2/112 [00:03<03:02,  1.66s/it]
# Epochs 2/10. Running Loss:    1.0279:   3%|▎         | 3/112 [00:04<03:00,  1.66s/it]
# Epochs 2/10. Running Loss:    1.0434:   3%|▎         | 3/112 [00:05<03:00,  1.66s/it]
# Epochs 2/10. Running Loss:    1.0434:   4%|▎         | 4/112 [00:06<03:00,  1.67s/it]
# Epochs 2/10. Running Loss:    0.9610:   4%|▎         | 4/112 [00:07<03:00,  1.67s/it]
# Epochs 2/10. Running Loss:    0.9610:   4%|▍         | 5/112 [00:08<02:57,  1.66s/it]
# Epochs 2/10. Running Loss:    0.9636:   4%|▍         | 5/112 [00:08<02:57,  1.66s/it]
# Epochs 2/10. Running Loss:    0.9636:   5%|▌         | 6/112 [00:09<02:56,  1.66s/it]
# Epochs 2/10. Running Loss:    1.0143:   5%|▌         | 6/112 [00:10<02:56,  1.66s/it]
# Epochs 2/10. Running Loss:    1.0143:   6%|▋         | 7/112 [00:11<02:55,  1.67s/it]
# Epochs 2/10. Running Loss:    0.9312:   6%|▋         | 7/112 [00:12<02:55,  1.67s/it]
# Epochs 2/10. Running Loss:    0.9312:   7%|▋         | 8/112 [00:13<02:53,  1.67s/it]
# Epochs 2/10. Running Loss:    0.9469:   7%|▋         | 8/112 [00:13<02:53,  1.67s/it]
# Epochs 2/10. Running Loss:    0.9469:   8%|▊         | 9/112 [00:14<02:51,  1.66s/it]
# Epochs 2/10. Running Loss:    0.8938:   8%|▊         | 9/112 [00:15<02:51,  1.66s/it]
# Epochs 2/10. Running Loss:    0.8938:   9%|▉         | 10/112 [00:16<02:50,  1.67s/it]
# Epochs 2/10. Running Loss:    0.8224:   9%|▉         | 10/112 [00:17<02:50,  1.67s/it]
# Epochs 2/10. Running Loss:    0.8224:  10%|▉         | 11/112 [00:18<02:50,  1.69s/it]
# Epochs 2/10. Running Loss:    1.0029:  10%|▉         | 11/112 [00:18<02:50,  1.69s/it]
# Epochs 2/10. Running Loss:    1.0029:  11%|█         | 12/112 [00:20<02:47,  1.68s/it]
# Epochs 2/10. Running Loss:    0.8595:  11%|█         | 12/112 [00:20<02:47,  1.68s/it]
# Epochs 2/10. Running Loss:    0.8595:  12%|█▏        | 13/112 [00:21<02:48,  1.70s/it]
# Epochs 2/10. Running Loss:    0.8629:  12%|█▏        | 13/112 [00:22<02:48,  1.70s/it]
# Epochs 2/10. Running Loss:    0.8629:  12%|█▎        | 14/112 [00:23<02:50,  1.74s/it]
# Epochs 2/10. Running Loss:    0.9762:  12%|█▎        | 14/112 [00:24<02:50,  1.74s/it]
# Epochs 2/10. Running Loss:    0.9762:  13%|█▎        | 15/112 [00:25<02:49,  1.74s/it]
# Epochs 2/10. Running Loss:    1.0811:  13%|█▎        | 15/112 [00:25<02:49,  1.74s/it]C:\Users\Precision5570\anaconda3\envs\TextMining5\Lib\site-packages\simpletransformers\classification\classification_model.py:1452: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   warnings.warn(
#
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# 2it [00:12,  6.08s/it]
#
# Epochs 2/10. Running Loss:    1.0811:  14%|█▍        | 16/112 [00:46<12:19,  7.70s/it]
# Epochs 2/10. Running Loss:    0.8181:  14%|█▍        | 16/112 [00:47<12:19,  7.70s/it]
# Epochs 2/10. Running Loss:    0.8181:  15%|█▌        | 17/112 [00:48<09:26,  5.97s/it]
# Epochs 2/10. Running Loss:    0.8892:  15%|█▌        | 17/112 [00:49<09:26,  5.97s/it]
# Epochs 2/10. Running Loss:    0.8892:  16%|█▌        | 18/112 [00:50<07:19,  4.68s/it]
# Epochs 2/10. Running Loss:    0.7911:  16%|█▌        | 18/112 [00:51<07:19,  4.68s/it]
# Epochs 2/10. Running Loss:    0.7911:  17%|█▋        | 19/112 [00:52<05:52,  3.79s/it]
# Epochs 2/10. Running Loss:    0.9236:  17%|█▋        | 19/112 [00:52<05:52,  3.79s/it]
# Epochs 2/10. Running Loss:    0.9236:  18%|█▊        | 20/112 [00:53<04:49,  3.15s/it]
# Epochs 2/10. Running Loss:    0.8655:  18%|█▊        | 20/112 [00:54<04:49,  3.15s/it]
# Epochs 2/10. Running Loss:    0.8655:  19%|█▉        | 21/112 [00:55<04:06,  2.70s/it]
# Epochs 2/10. Running Loss:    0.9397:  19%|█▉        | 21/112 [00:56<04:06,  2.70s/it]
# Epochs 2/10. Running Loss:    0.9397:  20%|█▉        | 22/112 [00:57<03:36,  2.40s/it]
# Epochs 2/10. Running Loss:    0.8234:  20%|█▉        | 22/112 [00:57<03:36,  2.40s/it]
# Epochs 2/10. Running Loss:    0.8234:  21%|██        | 23/112 [00:58<03:14,  2.18s/it]
# Epochs 2/10. Running Loss:    0.9713:  21%|██        | 23/112 [00:59<03:14,  2.18s/it]
# Epochs 2/10. Running Loss:    0.9713:  21%|██▏       | 24/112 [01:00<02:59,  2.04s/it]
# Epochs 2/10. Running Loss:    0.9441:  21%|██▏       | 24/112 [01:01<02:59,  2.04s/it]
# Epochs 2/10. Running Loss:    0.9441:  22%|██▏       | 25/112 [01:02<02:47,  1.93s/it]
# Epochs 2/10. Running Loss:    0.9912:  22%|██▏       | 25/112 [01:02<02:47,  1.93s/it]
# Epochs 2/10. Running Loss:    0.9912:  23%|██▎       | 26/112 [01:03<02:38,  1.84s/it]
# Epochs 2/10. Running Loss:    0.8659:  23%|██▎       | 26/112 [01:04<02:38,  1.84s/it]
# Epochs 2/10. Running Loss:    0.8659:  24%|██▍       | 27/112 [01:05<02:32,  1.79s/it]
# Epochs 2/10. Running Loss:    0.8142:  24%|██▍       | 27/112 [01:06<02:32,  1.79s/it]
# Epochs 2/10. Running Loss:    0.8142:  25%|██▌       | 28/112 [01:07<02:27,  1.75s/it]
# Epochs 2/10. Running Loss:    0.9819:  25%|██▌       | 28/112 [01:07<02:27,  1.75s/it]
# Epochs 2/10. Running Loss:    0.9819:  26%|██▌       | 29/112 [01:08<02:23,  1.73s/it]
# Epochs 2/10. Running Loss:    0.9089:  26%|██▌       | 29/112 [01:09<02:23,  1.73s/it]
# Epochs 2/10. Running Loss:    0.9089:  27%|██▋       | 30/112 [01:10<02:20,  1.71s/it]
# Epochs 2/10. Running Loss:    0.9022:  27%|██▋       | 30/112 [01:11<02:20,  1.71s/it]
# Epochs 2/10. Running Loss:    0.9022:  28%|██▊       | 31/112 [01:12<02:19,  1.72s/it]
# Epochs 2/10. Running Loss:    0.8735:  28%|██▊       | 31/112 [01:13<02:19,  1.72s/it]
# Epochs 2/10. Running Loss:    0.8735:  29%|██▊       | 32/112 [01:14<02:19,  1.74s/it]
# Epochs 2/10. Running Loss:    0.9720:  29%|██▊       | 32/112 [01:14<02:19,  1.74s/it]
# Epochs 2/10. Running Loss:    0.9720:  29%|██▉       | 33/112 [01:15<02:16,  1.73s/it]
# Epochs 2/10. Running Loss:    0.8510:  29%|██▉       | 33/112 [01:16<02:16,  1.73s/it]
# Epochs 2/10. Running Loss:    0.8510:  30%|███       | 34/112 [01:17<02:13,  1.71s/it]
# Epochs 2/10. Running Loss:    0.8498:  30%|███       | 34/112 [01:18<02:13,  1.71s/it]
# Epochs 2/10. Running Loss:    0.8498:  31%|███▏      | 35/112 [01:19<02:12,  1.72s/it]
# Epochs 2/10. Running Loss:    0.8529:  31%|███▏      | 35/112 [01:19<02:12,  1.72s/it]
# Epochs 2/10. Running Loss:    0.8529:  32%|███▏      | 36/112 [01:21<02:12,  1.75s/it]
# Epochs 2/10. Running Loss:    1.0088:  32%|███▏      | 36/112 [01:21<02:12,  1.75s/it]
# Epochs 2/10. Running Loss:    1.0088:  33%|███▎      | 37/112 [01:22<02:09,  1.72s/it]
# Epochs 2/10. Running Loss:    0.9648:  33%|███▎      | 37/112 [01:23<02:09,  1.72s/it]
# Epochs 2/10. Running Loss:    0.9648:  34%|███▍      | 38/112 [01:24<02:05,  1.70s/it]
# Epochs 2/10. Running Loss:    0.9156:  34%|███▍      | 38/112 [01:25<02:05,  1.70s/it]
# Epochs 2/10. Running Loss:    0.9156:  35%|███▍      | 39/112 [01:26<02:03,  1.69s/it]
# Epochs 2/10. Running Loss:    0.8549:  35%|███▍      | 39/112 [01:26<02:03,  1.69s/it]
# Epochs 2/10. Running Loss:    0.8549:  36%|███▌      | 40/112 [01:27<02:01,  1.68s/it]
# Epochs 2/10. Running Loss:    0.8937:  36%|███▌      | 40/112 [01:28<02:01,  1.68s/it]
# Epochs 2/10. Running Loss:    0.8937:  37%|███▋      | 41/112 [01:29<01:59,  1.68s/it]
# Epochs 2/10. Running Loss:    0.8437:  37%|███▋      | 41/112 [01:30<01:59,  1.68s/it]
# Epochs 2/10. Running Loss:    0.8437:  38%|███▊      | 42/112 [01:31<01:58,  1.70s/it]
# Epochs 2/10. Running Loss:    0.8259:  38%|███▊      | 42/112 [01:31<01:58,  1.70s/it]
# Epochs 2/10. Running Loss:    0.8259:  38%|███▊      | 43/112 [01:32<01:58,  1.71s/it]
# Epochs 2/10. Running Loss:    0.8222:  38%|███▊      | 43/112 [01:33<01:58,  1.71s/it]
# Epochs 2/10. Running Loss:    0.8222:  39%|███▉      | 44/112 [01:34<01:55,  1.70s/it]
# Epochs 2/10. Running Loss:    0.9648:  39%|███▉      | 44/112 [01:35<01:55,  1.70s/it]
# Epochs 2/10. Running Loss:    0.9648:  40%|████      | 45/112 [01:36<01:53,  1.69s/it]
# Epochs 2/10. Running Loss:    0.8076:  40%|████      | 45/112 [01:36<01:53,  1.69s/it]
# Epochs 2/10. Running Loss:    0.8076:  41%|████      | 46/112 [01:37<01:52,  1.70s/it]
# Epochs 2/10. Running Loss:    0.8991:  41%|████      | 46/112 [01:38<01:52,  1.70s/it]
# Epochs 2/10. Running Loss:    0.8991:  42%|████▏     | 47/112 [01:39<01:52,  1.73s/it]
# Epochs 2/10. Running Loss:    0.8737:  42%|████▏     | 47/112 [01:40<01:52,  1.73s/it]C:\Users\Precision5570\anaconda3\envs\TextMining5\Lib\site-packages\simpletransformers\classification\classification_model.py:1452: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   warnings.warn(
#
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# 2it [00:12,  6.02s/it]
#
# Epochs 2/10. Running Loss:    0.8737:  43%|████▎     | 48/112 [02:01<08:07,  7.61s/it]
# Epochs 2/10. Running Loss:    0.7489:  43%|████▎     | 48/112 [02:01<08:07,  7.61s/it]
# Epochs 2/10. Running Loss:    0.7489:  44%|████▍     | 49/112 [02:02<06:10,  5.88s/it]
# Epochs 2/10. Running Loss:    0.9015:  44%|████▍     | 49/112 [02:03<06:10,  5.88s/it]
# Epochs 2/10. Running Loss:    0.9015:  45%|████▍     | 50/112 [02:04<04:45,  4.61s/it]
# Epochs 2/10. Running Loss:    0.9493:  45%|████▍     | 50/112 [02:05<04:45,  4.61s/it]
# Epochs 2/10. Running Loss:    0.9493:  46%|████▌     | 51/112 [02:06<03:47,  3.73s/it]
# Epochs 2/10. Running Loss:    0.7962:  46%|████▌     | 51/112 [02:06<03:47,  3.73s/it]
# Epochs 2/10. Running Loss:    0.7962:  46%|████▋     | 52/112 [02:07<03:07,  3.13s/it]
# Epochs 2/10. Running Loss:    0.9174:  46%|████▋     | 52/112 [02:08<03:07,  3.13s/it]
# Epochs 2/10. Running Loss:    0.9174:  47%|████▋     | 53/112 [02:09<02:39,  2.71s/it]
# Epochs 2/10. Running Loss:    0.9390:  47%|████▋     | 53/112 [02:10<02:39,  2.71s/it]
# Epochs 2/10. Running Loss:    0.9390:  48%|████▊     | 54/112 [02:11<02:19,  2.40s/it]
# Epochs 2/10. Running Loss:    0.8007:  48%|████▊     | 54/112 [02:12<02:19,  2.40s/it]
# Epochs 2/10. Running Loss:    0.8007:  49%|████▉     | 55/112 [02:13<02:04,  2.18s/it]
# Epochs 2/10. Running Loss:    0.9628:  49%|████▉     | 55/112 [02:13<02:04,  2.18s/it]
# Epochs 2/10. Running Loss:    0.9628:  50%|█████     | 56/112 [02:14<01:53,  2.03s/it]
# Epochs 2/10. Running Loss:    0.9373:  50%|█████     | 56/112 [02:15<01:53,  2.03s/it]
# Epochs 2/10. Running Loss:    0.9373:  51%|█████     | 57/112 [02:16<01:44,  1.91s/it]
# Epochs 2/10. Running Loss:    0.9603:  51%|█████     | 57/112 [02:16<01:44,  1.91s/it]
# Epochs 2/10. Running Loss:    0.9603:  52%|█████▏    | 58/112 [02:18<01:38,  1.83s/it]
# Epochs 2/10. Running Loss:    0.9279:  52%|█████▏    | 58/112 [02:18<01:38,  1.83s/it]
# Epochs 2/10. Running Loss:    0.9279:  53%|█████▎    | 59/112 [02:19<01:34,  1.78s/it]
# Epochs 2/10. Running Loss:    0.8937:  53%|█████▎    | 59/112 [02:20<01:34,  1.78s/it]
# Epochs 2/10. Running Loss:    0.8937:  54%|█████▎    | 60/112 [02:21<01:30,  1.75s/it]
# Epochs 2/10. Running Loss:    0.9392:  54%|█████▎    | 60/112 [02:21<01:30,  1.75s/it]
# Epochs 2/10. Running Loss:    0.9392:  54%|█████▍    | 61/112 [02:23<01:28,  1.74s/it]
# Epochs 2/10. Running Loss:    0.9305:  54%|█████▍    | 61/112 [02:23<01:28,  1.74s/it]
# Epochs 2/10. Running Loss:    0.9305:  55%|█████▌    | 62/112 [02:24<01:25,  1.72s/it]
# Epochs 2/10. Running Loss:    0.7730:  55%|█████▌    | 62/112 [02:25<01:25,  1.72s/it]
# Epochs 2/10. Running Loss:    0.7730:  56%|█████▋    | 63/112 [02:26<01:23,  1.70s/it]
# Epochs 2/10. Running Loss:    1.0681:  56%|█████▋    | 63/112 [02:27<01:23,  1.70s/it]
# Epochs 2/10. Running Loss:    1.0681:  57%|█████▋    | 64/112 [02:28<01:21,  1.69s/it]
# Epochs 2/10. Running Loss:    0.8693:  57%|█████▋    | 64/112 [02:28<01:21,  1.69s/it]
# Epochs 2/10. Running Loss:    0.8693:  58%|█████▊    | 65/112 [02:29<01:18,  1.68s/it]
# Epochs 2/10. Running Loss:    0.7234:  58%|█████▊    | 65/112 [02:30<01:18,  1.68s/it]
# Epochs 2/10. Running Loss:    0.7234:  59%|█████▉    | 66/112 [02:31<01:17,  1.68s/it]
# Epochs 2/10. Running Loss:    0.9702:  59%|█████▉    | 66/112 [02:32<01:17,  1.68s/it]
# Epochs 2/10. Running Loss:    0.9702:  60%|█████▉    | 67/112 [02:33<01:15,  1.67s/it]
# Epochs 2/10. Running Loss:    0.9858:  60%|█████▉    | 67/112 [02:33<01:15,  1.67s/it]
# Epochs 2/10. Running Loss:    0.9858:  61%|██████    | 68/112 [02:34<01:13,  1.67s/it]
# Epochs 2/10. Running Loss:    0.7395:  61%|██████    | 68/112 [02:35<01:13,  1.67s/it]
# Epochs 2/10. Running Loss:    0.7395:  62%|██████▏   | 69/112 [02:36<01:12,  1.68s/it]
# Epochs 2/10. Running Loss:    0.8988:  62%|██████▏   | 69/112 [02:37<01:12,  1.68s/it]
# Epochs 2/10. Running Loss:    0.8988:  62%|██████▎   | 70/112 [02:38<01:10,  1.68s/it]
# Epochs 2/10. Running Loss:    0.8417:  62%|██████▎   | 70/112 [02:38<01:10,  1.68s/it]
# Epochs 2/10. Running Loss:    0.8417:  63%|██████▎   | 71/112 [02:39<01:08,  1.68s/it]
# Epochs 2/10. Running Loss:    0.9014:  63%|██████▎   | 71/112 [02:40<01:08,  1.68s/it]
# Epochs 2/10. Running Loss:    0.9014:  64%|██████▍   | 72/112 [02:41<01:07,  1.69s/it]
# Epochs 2/10. Running Loss:    0.7819:  64%|██████▍   | 72/112 [02:42<01:07,  1.69s/it]
# Epochs 2/10. Running Loss:    0.7819:  65%|██████▌   | 73/112 [02:43<01:06,  1.69s/it]
# Epochs 2/10. Running Loss:    0.8519:  65%|██████▌   | 73/112 [02:43<01:06,  1.69s/it]
# Epochs 2/10. Running Loss:    0.8519:  66%|██████▌   | 74/112 [02:44<01:04,  1.68s/it]
# Epochs 2/10. Running Loss:    0.8854:  66%|██████▌   | 74/112 [02:45<01:04,  1.68s/it]
# Epochs 2/10. Running Loss:    0.8854:  67%|██████▋   | 75/112 [02:46<01:02,  1.68s/it]
# Epochs 2/10. Running Loss:    0.9724:  67%|██████▋   | 75/112 [02:47<01:02,  1.68s/it]
# Epochs 2/10. Running Loss:    0.9724:  68%|██████▊   | 76/112 [02:48<01:00,  1.69s/it]
# Epochs 2/10. Running Loss:    0.7935:  68%|██████▊   | 76/112 [02:48<01:00,  1.69s/it]
# Epochs 2/10. Running Loss:    0.7935:  69%|██████▉   | 77/112 [02:49<00:58,  1.69s/it]
# Epochs 2/10. Running Loss:    0.9181:  69%|██████▉   | 77/112 [02:50<00:58,  1.69s/it]
# Epochs 2/10. Running Loss:    0.9181:  70%|██████▉   | 78/112 [02:51<00:57,  1.68s/it]
# Epochs 2/10. Running Loss:    0.8625:  70%|██████▉   | 78/112 [02:52<00:57,  1.68s/it]
# Epochs 2/10. Running Loss:    0.8625:  71%|███████   | 79/112 [02:53<00:55,  1.67s/it]
# Epochs 2/10. Running Loss:    0.8676:  71%|███████   | 79/112 [02:53<00:55,  1.67s/it]C:\Users\Precision5570\anaconda3\envs\TextMining5\Lib\site-packages\simpletransformers\classification\classification_model.py:1452: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   warnings.warn(
#
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# 2it [00:12,  6.02s/it]
#
# Epochs 2/10. Running Loss:    0.8676:  71%|███████▏  | 80/112 [03:14<04:02,  7.57s/it]
# Epochs 2/10. Running Loss:    0.8646:  71%|███████▏  | 80/112 [03:15<04:02,  7.57s/it]
# Epochs 2/10. Running Loss:    0.8646:  72%|███████▏  | 81/112 [03:16<02:59,  5.81s/it]
# Epochs 2/10. Running Loss:    0.8153:  72%|███████▏  | 81/112 [03:16<02:59,  5.81s/it]
# Epochs 2/10. Running Loss:    0.8153:  73%|███████▎  | 82/112 [03:17<02:17,  4.57s/it]
# Epochs 2/10. Running Loss:    0.8969:  73%|███████▎  | 82/112 [03:18<02:17,  4.57s/it]
# Epochs 2/10. Running Loss:    0.8969:  74%|███████▍  | 83/112 [03:19<01:47,  3.70s/it]
# Epochs 2/10. Running Loss:    0.7478:  74%|███████▍  | 83/112 [03:20<01:47,  3.70s/it]
# Epochs 2/10. Running Loss:    0.7478:  75%|███████▌  | 84/112 [03:21<01:27,  3.11s/it]
# Epochs 2/10. Running Loss:    0.9035:  75%|███████▌  | 84/112 [03:21<01:27,  3.11s/it]
# Epochs 2/10. Running Loss:    0.9035:  76%|███████▌  | 85/112 [03:23<01:12,  2.69s/it]
# Epochs 2/10. Running Loss:    0.9608:  76%|███████▌  | 85/112 [03:23<01:12,  2.69s/it]
# Epochs 2/10. Running Loss:    0.9608:  77%|███████▋  | 86/112 [03:24<01:02,  2.41s/it]
# Epochs 2/10. Running Loss:    0.8238:  77%|███████▋  | 86/112 [03:25<01:02,  2.41s/it]
# Epochs 2/10. Running Loss:    0.8238:  78%|███████▊  | 87/112 [03:26<00:54,  2.20s/it]
# Epochs 2/10. Running Loss:    0.8893:  78%|███████▊  | 87/112 [03:27<00:54,  2.20s/it]
# Epochs 2/10. Running Loss:    0.8893:  79%|███████▊  | 88/112 [03:28<00:49,  2.06s/it]
# Epochs 2/10. Running Loss:    0.7865:  79%|███████▊  | 88/112 [03:28<00:49,  2.06s/it]
# Epochs 2/10. Running Loss:    0.7865:  79%|███████▉  | 89/112 [03:29<00:45,  1.96s/it]
# Epochs 2/10. Running Loss:    0.8375:  79%|███████▉  | 89/112 [03:30<00:45,  1.96s/it]
# Epochs 2/10. Running Loss:    0.8375:  80%|████████  | 90/112 [03:31<00:41,  1.87s/it]
# Epochs 2/10. Running Loss:    0.8775:  80%|████████  | 90/112 [03:32<00:41,  1.87s/it]
# Epochs 2/10. Running Loss:    0.8775:  81%|████████▏ | 91/112 [03:33<00:38,  1.83s/it]
# Epochs 2/10. Running Loss:    0.8345:  81%|████████▏ | 91/112 [03:33<00:38,  1.83s/it]
# Epochs 2/10. Running Loss:    0.8345:  82%|████████▏ | 92/112 [03:35<00:35,  1.78s/it]
# Epochs 2/10. Running Loss:    0.9468:  82%|████████▏ | 92/112 [03:35<00:35,  1.78s/it]
# Epochs 2/10. Running Loss:    0.9468:  83%|████████▎ | 93/112 [03:36<00:33,  1.77s/it]
# Epochs 2/10. Running Loss:    0.8249:  83%|████████▎ | 93/112 [03:37<00:33,  1.77s/it]
# Epochs 2/10. Running Loss:    0.8249:  84%|████████▍ | 94/112 [03:38<00:31,  1.76s/it]
# Epochs 2/10. Running Loss:    0.8419:  84%|████████▍ | 94/112 [03:39<00:31,  1.76s/it]
# Epochs 2/10. Running Loss:    0.8419:  85%|████████▍ | 95/112 [03:40<00:29,  1.74s/it]
# Epochs 2/10. Running Loss:    0.8730:  85%|████████▍ | 95/112 [03:40<00:29,  1.74s/it]
# Epochs 2/10. Running Loss:    0.8730:  86%|████████▌ | 96/112 [03:41<00:27,  1.74s/it]
# Epochs 2/10. Running Loss:    0.8951:  86%|████████▌ | 96/112 [03:42<00:27,  1.74s/it]
# Epochs 2/10. Running Loss:    0.8951:  87%|████████▋ | 97/112 [03:43<00:25,  1.73s/it]
# Epochs 2/10. Running Loss:    0.7437:  87%|████████▋ | 97/112 [03:44<00:25,  1.73s/it]
# Epochs 2/10. Running Loss:    0.7437:  88%|████████▊ | 98/112 [03:45<00:24,  1.73s/it]
# Epochs 2/10. Running Loss:    0.8341:  88%|████████▊ | 98/112 [03:45<00:24,  1.73s/it]
# Epochs 2/10. Running Loss:    0.8341:  88%|████████▊ | 99/112 [03:47<00:22,  1.71s/it]
# Epochs 2/10. Running Loss:    0.7833:  88%|████████▊ | 99/112 [03:47<00:22,  1.71s/it]
# Epochs 2/10. Running Loss:    0.7833:  89%|████████▉ | 100/112 [03:48<00:20,  1.71s/it]
# Epochs 2/10. Running Loss:    0.9414:  89%|████████▉ | 100/112 [03:49<00:20,  1.71s/it]
# Epochs 2/10. Running Loss:    0.9414:  90%|█████████ | 101/112 [03:50<00:18,  1.70s/it]
# Epochs 2/10. Running Loss:    0.9855:  90%|█████████ | 101/112 [03:51<00:18,  1.70s/it]
# Epochs 2/10. Running Loss:    0.9855:  91%|█████████ | 102/112 [03:52<00:16,  1.69s/it]
# Epochs 2/10. Running Loss:    0.9588:  91%|█████████ | 102/112 [03:52<00:16,  1.69s/it]
# Epochs 2/10. Running Loss:    0.9588:  92%|█████████▏| 103/112 [03:53<00:15,  1.68s/it]
# Epochs 2/10. Running Loss:    0.9875:  92%|█████████▏| 103/112 [03:54<00:15,  1.68s/it]
# Epochs 2/10. Running Loss:    0.9875:  93%|█████████▎| 104/112 [03:55<00:13,  1.68s/it]
# Epochs 2/10. Running Loss:    0.9879:  93%|█████████▎| 104/112 [03:56<00:13,  1.68s/it]
# Epochs 2/10. Running Loss:    0.9879:  94%|█████████▍| 105/112 [03:57<00:11,  1.67s/it]
# Epochs 2/10. Running Loss:    0.7798:  94%|█████████▍| 105/112 [03:57<00:11,  1.67s/it]
# Epochs 2/10. Running Loss:    0.7798:  95%|█████████▍| 106/112 [03:58<00:10,  1.71s/it]
# Epochs 2/10. Running Loss:    0.9262:  95%|█████████▍| 106/112 [03:59<00:10,  1.71s/it]
# Epochs 2/10. Running Loss:    0.9262:  96%|█████████▌| 107/112 [04:00<00:08,  1.75s/it]
# Epochs 2/10. Running Loss:    0.8197:  96%|█████████▌| 107/112 [04:01<00:08,  1.75s/it]
# Epochs 2/10. Running Loss:    0.8197:  96%|█████████▋| 108/112 [04:02<00:07,  1.78s/it]
# Epochs 2/10. Running Loss:    0.8488:  96%|█████████▋| 108/112 [04:03<00:07,  1.78s/it]
# Epochs 2/10. Running Loss:    0.8488:  97%|█████████▋| 109/112 [04:04<00:05,  1.79s/it]
# Epochs 2/10. Running Loss:    0.9214:  97%|█████████▋| 109/112 [04:04<00:05,  1.79s/it]
# Epochs 2/10. Running Loss:    0.9214:  98%|█████████▊| 110/112 [04:06<00:03,  1.75s/it]
# Epochs 2/10. Running Loss:    0.8093:  98%|█████████▊| 110/112 [04:06<00:03,  1.75s/it]
# Epochs 2/10. Running Loss:    0.8093:  99%|█████████▉| 111/112 [04:07<00:01,  1.72s/it]
# Epochs 2/10. Running Loss:    0.8432:  99%|█████████▉| 111/112 [04:07<00:01,  1.72s/it]C:\Users\Precision5570\anaconda3\envs\TextMining5\Lib\site-packages\simpletransformers\classification\classification_model.py:1452: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   warnings.warn(
#
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# 2it [00:11,  5.88s/it]
#
# Epochs 2/10. Running Loss:    0.8432: 100%|██████████| 112/112 [04:27<00:00,  2.39s/it]
# C:\Users\Precision5570\anaconda3\envs\TextMining5\Lib\site-packages\simpletransformers\classification\classification_model.py:1452: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   warnings.warn(
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 2it [00:12,  6.08s/it]
# Epoch 3 of 10:  20%|██        | 2/10 [10:16<40:35, 304.45s/it]
# Running Epoch 3 of 10:   0%|          | 0/112 [00:00<?, ?it/s]
# Epochs 3/10. Running Loss:    0.6877:   0%|          | 0/112 [00:00<?, ?it/s]
# Epochs 3/10. Running Loss:    0.6877:   1%|          | 1/112 [00:01<02:58,  1.61s/it]
# Epochs 3/10. Running Loss:    0.8909:   1%|          | 1/112 [00:02<02:58,  1.61s/it]
# Epochs 3/10. Running Loss:    0.8909:   2%|▏         | 2/112 [00:03<03:02,  1.66s/it]
# Epochs 3/10. Running Loss:    0.6544:   2%|▏         | 2/112 [00:03<03:02,  1.66s/it]
# Epochs 3/10. Running Loss:    0.6544:   3%|▎         | 3/112 [00:04<03:01,  1.66s/it]
# Epochs 3/10. Running Loss:    0.8566:   3%|▎         | 3/112 [00:05<03:01,  1.66s/it]
# Epochs 3/10. Running Loss:    0.8566:   4%|▎         | 4/112 [00:06<02:59,  1.66s/it]
# Epochs 3/10. Running Loss:    0.9590:   4%|▎         | 4/112 [00:07<02:59,  1.66s/it]
# Epochs 3/10. Running Loss:    0.9590:   4%|▍         | 5/112 [00:08<02:57,  1.66s/it]
# Epochs 3/10. Running Loss:    0.7279:   4%|▍         | 5/112 [00:08<02:57,  1.66s/it]
# Epochs 3/10. Running Loss:    0.7279:   5%|▌         | 6/112 [00:09<02:55,  1.66s/it]
# Epochs 3/10. Running Loss:    0.8778:   5%|▌         | 6/112 [00:10<02:55,  1.66s/it]
# Epochs 3/10. Running Loss:    0.8778:   6%|▋         | 7/112 [00:11<02:55,  1.67s/it]
# Epochs 3/10. Running Loss:    0.7998:   6%|▋         | 7/112 [00:12<02:55,  1.67s/it]
# Epochs 3/10. Running Loss:    0.7998:   7%|▋         | 8/112 [00:13<02:53,  1.66s/it]
# Epochs 3/10. Running Loss:    0.8301:   7%|▋         | 8/112 [00:13<02:53,  1.66s/it]
# Epochs 3/10. Running Loss:    0.8301:   8%|▊         | 9/112 [00:14<02:50,  1.66s/it]
# Epochs 3/10. Running Loss:    0.9963:   8%|▊         | 9/112 [00:15<02:50,  1.66s/it]
# Epochs 3/10. Running Loss:    0.9963:   9%|▉         | 10/112 [00:16<02:49,  1.66s/it]
# Epochs 3/10. Running Loss:    0.8386:   9%|▉         | 10/112 [00:17<02:49,  1.66s/it]
# Epochs 3/10. Running Loss:    0.8386:  10%|▉         | 11/112 [00:18<02:48,  1.67s/it]
# Epochs 3/10. Running Loss:    0.8503:  10%|▉         | 11/112 [00:18<02:48,  1.67s/it]
# Epochs 3/10. Running Loss:    0.8503:  11%|█         | 12/112 [00:19<02:46,  1.67s/it]
# Epochs 3/10. Running Loss:    0.7529:  11%|█         | 12/112 [00:20<02:46,  1.67s/it]
# Epochs 3/10. Running Loss:    0.7529:  12%|█▏        | 13/112 [00:21<02:44,  1.66s/it]
# Epochs 3/10. Running Loss:    0.8589:  12%|█▏        | 13/112 [00:22<02:44,  1.66s/it]
# Epochs 3/10. Running Loss:    0.8589:  12%|█▎        | 14/112 [00:23<02:43,  1.66s/it]
# Epochs 3/10. Running Loss:    0.8401:  12%|█▎        | 14/112 [00:23<02:43,  1.66s/it]
# Epochs 3/10. Running Loss:    0.8401:  13%|█▎        | 15/112 [00:24<02:42,  1.67s/it]
# Epochs 3/10. Running Loss:    0.9099:  13%|█▎        | 15/112 [00:25<02:42,  1.67s/it]
# Epochs 3/10. Running Loss:    0.9099:  14%|█▍        | 16/112 [00:26<02:39,  1.67s/it]
# Epochs 3/10. Running Loss:    0.9114:  14%|█▍        | 16/112 [00:27<02:39,  1.67s/it]
# Epochs 3/10. Running Loss:    0.9114:  15%|█▌        | 17/112 [00:28<02:38,  1.66s/it]
# Epochs 3/10. Running Loss:    0.7003:  15%|█▌        | 17/112 [00:28<02:38,  1.66s/it]
# Epochs 3/10. Running Loss:    0.7003:  16%|█▌        | 18/112 [00:29<02:36,  1.66s/it]
# Epochs 3/10. Running Loss:    0.7662:  16%|█▌        | 18/112 [00:30<02:36,  1.66s/it]
# Epochs 3/10. Running Loss:    0.7662:  17%|█▋        | 19/112 [00:31<02:35,  1.67s/it]
# Epochs 3/10. Running Loss:    0.7624:  17%|█▋        | 19/112 [00:32<02:35,  1.67s/it]
# Epochs 3/10. Running Loss:    0.7624:  18%|█▊        | 20/112 [00:33<02:33,  1.67s/it]
# Epochs 3/10. Running Loss:    0.7534:  18%|█▊        | 20/112 [00:33<02:33,  1.67s/it]
# Epochs 3/10. Running Loss:    0.7534:  19%|█▉        | 21/112 [00:34<02:31,  1.66s/it]
# Epochs 3/10. Running Loss:    0.8868:  19%|█▉        | 21/112 [00:35<02:31,  1.66s/it]
# Epochs 3/10. Running Loss:    0.8868:  20%|█▉        | 22/112 [00:36<02:30,  1.67s/it]
# Epochs 3/10. Running Loss:    0.7889:  20%|█▉        | 22/112 [00:37<02:30,  1.67s/it]
# Epochs 3/10. Running Loss:    0.7889:  21%|██        | 23/112 [00:38<02:28,  1.67s/it]
# Epochs 3/10. Running Loss:    0.7189:  21%|██        | 23/112 [00:38<02:28,  1.67s/it]
# Epochs 3/10. Running Loss:    0.7189:  21%|██▏       | 24/112 [00:39<02:26,  1.67s/it]
# Epochs 3/10. Running Loss:    0.7147:  21%|██▏       | 24/112 [00:40<02:26,  1.67s/it]
# Epochs 3/10. Running Loss:    0.7147:  22%|██▏       | 25/112 [00:41<02:24,  1.66s/it]
# Epochs 3/10. Running Loss:    1.0938:  22%|██▏       | 25/112 [00:42<02:24,  1.66s/it]
# Epochs 3/10. Running Loss:    1.0938:  23%|██▎       | 26/112 [00:43<02:22,  1.66s/it]
# Epochs 3/10. Running Loss:    0.7983:  23%|██▎       | 26/112 [00:43<02:22,  1.66s/it]
# Epochs 3/10. Running Loss:    0.7983:  24%|██▍       | 27/112 [00:44<02:20,  1.66s/it]
# Epochs 3/10. Running Loss:    0.8627:  24%|██▍       | 27/112 [00:45<02:20,  1.66s/it]
# Epochs 3/10. Running Loss:    0.8627:  25%|██▌       | 28/112 [00:46<02:19,  1.66s/it]
# Epochs 3/10. Running Loss:    0.6968:  25%|██▌       | 28/112 [00:47<02:19,  1.66s/it]
# ...
# Epochs 6/10. Running Loss:    0.6898:  84%|████████▍ | 94/112 [03:30<00:30,  1.70s/it]
# Epochs 6/10. Running Loss:    0.5506:  84%|████████▍ | 94/112 [03:30<00:30,  1.70s/it]
# Epochs 6/10. Running Loss:    0.5506:  85%|████████▍ | 95/112 [03:32<00:28,  1.69s/it]
# Epochs 6/10. Running Loss:    0.5015:  85%|████████▍ | 95/112 [03:32<00:28,  1.69s/it]
# Epochs 6/10. Running Loss:    0.5015:  86%|████████▌ | 96/112 [03:33<00:27,  1.69s/it]
# Epochs 6/10. Running Loss:    0.7798:  86%|████████▌ | 96/112 [03:34<00:27,  1.69s/it]
# Epochs 6/10. Running Loss:    0.7798:  87%|████████▋ | 97/112 [03:35<00:25,  1.68s/it]
# Epochs 6/10. Running Loss:    0.7890:  87%|████████▋ | 97/112 [03:35<00:25,  1.68s/it]
# Epochs 6/10. Running Loss:    0.7890:  88%|████████▊ | 98/112 [03:37<00:23,  1.67s/it]
# Epochs 6/10. Running Loss:    0.6410:  88%|████████▊ | 98/112 [03:37<00:23,  1.67s/it]
# Epochs 6/10. Running Loss:    0.6410:  88%|████████▊ | 99/112 [03:38<00:21,  1.66s/it]
# Epochs 6/10. Running Loss:    0.5181:  88%|████████▊ | 99/112 [03:39<00:21,  1.66s/it]
# Epochs 6/10. Running Loss:    0.5181:  89%|████████▉ | 100/112 [03:40<00:20,  1.67s/it]
# Epochs 6/10. Running Loss:    0.5209:  89%|████████▉ | 100/112 [03:40<00:20,  1.67s/it]
# Epochs 6/10. Running Loss:    0.5209:  90%|█████████ | 101/112 [03:42<00:18,  1.67s/it]
# Epochs 6/10. Running Loss:    0.6766:  90%|█████████ | 101/112 [03:42<00:18,  1.67s/it]
# Epochs 6/10. Running Loss:    0.6766:  91%|█████████ | 102/112 [03:43<00:16,  1.66s/it]
# Epochs 6/10. Running Loss:    0.4773:  91%|█████████ | 102/112 [03:44<00:16,  1.66s/it]
# Epochs 6/10. Running Loss:    0.4773:  92%|█████████▏| 103/112 [03:45<00:15,  1.67s/it]
# Epochs 6/10. Running Loss:    0.4728:  92%|█████████▏| 103/112 [03:45<00:15,  1.67s/it]
# Epochs 6/10. Running Loss:    0.4728:  93%|█████████▎| 104/112 [03:47<00:13,  1.67s/it]
# Epochs 6/10. Running Loss:    0.5890:  93%|█████████▎| 104/112 [03:47<00:13,  1.67s/it]
# Epochs 6/10. Running Loss:    0.5890:  94%|█████████▍| 105/112 [03:48<00:11,  1.66s/it]
# Epochs 6/10. Running Loss:    0.4327:  94%|█████████▍| 105/112 [03:49<00:11,  1.66s/it]
# Epochs 6/10. Running Loss:    0.4327:  95%|█████████▍| 106/112 [03:50<00:09,  1.66s/it]
# Epochs 6/10. Running Loss:    0.6384:  95%|█████████▍| 106/112 [03:50<00:09,  1.66s/it]
# Epochs 6/10. Running Loss:    0.6384:  96%|█████████▌| 107/112 [03:51<00:08,  1.66s/it]
# Epochs 6/10. Running Loss:    0.4340:  96%|█████████▌| 107/112 [03:52<00:08,  1.66s/it]
# Epochs 6/10. Running Loss:    0.4340:  96%|█████████▋| 108/112 [03:53<00:06,  1.66s/it]
# Epochs 6/10. Running Loss:    0.7160:  96%|█████████▋| 108/112 [03:54<00:06,  1.66s/it]
# Epochs 6/10. Running Loss:    0.7160:  97%|█████████▋| 109/112 [03:55<00:04,  1.66s/it]
# Epochs 6/10. Running Loss:    0.4998:  97%|█████████▋| 109/112 [03:55<00:04,  1.66s/it]
# Epochs 6/10. Running Loss:    0.4998:  98%|█████████▊| 110/112 [03:56<00:03,  1.66s/it]
# Epochs 6/10. Running Loss:    0.7230:  98%|█████████▊| 110/112 [03:57<00:03,  1.66s/it]
# Epochs 6/10. Running Loss:    0.7230:  99%|█████████▉| 111/112 [03:58<00:01,  1.66s/it]
# Epochs 6/10. Running Loss:    0.6370:  99%|█████████▉| 111/112 [03:58<00:01,  1.66s/it]C:\Users\Precision5570\anaconda3\envs\TextMining5\Lib\site-packages\simpletransformers\classification\classification_model.py:1452: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   warnings.warn(
#
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# 2it [00:11,  5.80s/it]
#
# Epochs 6/10. Running Loss:    0.6370: 100%|██████████| 112/112 [04:16<00:00,  2.29s/it]
# C:\Users\Precision5570\anaconda3\envs\TextMining5\Lib\site-packages\simpletransformers\classification\classification_model.py:1452: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   warnings.warn(
#
#   0%|          | 0/1 [00:00<?, ?it/s]
# 2it [00:11,  5.82s/it]
# Epoch 7 of 10:  60%|██████    | 6/10 [28:15<18:18, 274.70s/it]
# Running Epoch 7 of 10:   0%|          | 0/112 [00:00<?, ?it/s]
# Epochs 7/10. Running Loss:    0.6049:   0%|          | 0/112 [00:00<?, ?it/s]
# Epochs 7/10. Running Loss:    0.6049:   1%|          | 1/112 [00:01<02:59,  1.62s/it]
# Epochs 7/10. Running Loss:    0.5669:   1%|          | 1/112 [00:02<02:59,  1.62s/it]
# Epochs 7/10. Running Loss:    0.5669:   2%|▏         | 2/112 [00:03<02:59,  1.63s/it]
# Epochs 7/10. Running Loss:    0.7603:   2%|▏         | 2/112 [00:03<02:59,  1.63s/it]
# Epochs 7/10. Running Loss:    0.7603:   3%|▎         | 3/112 [00:04<02:59,  1.64s/it]
# Epochs 7/10. Running Loss:    0.2326:   3%|▎         | 3/112 [00:05<02:59,  1.64s/it]
# Epochs 7/10. Running Loss:    0.2326:   4%|▎         | 4/112 [00:06<02:58,  1.65s/it]
# Epochs 7/10. Running Loss:    0.4537:   4%|▎         | 4/112 [00:07<02:58,  1.65s/it]
# Epochs 7/10. Running Loss:    0.4537:   4%|▍         | 5/112 [00:08<02:57,  1.65s/it]
# Epochs 7/10. Running Loss:    0.3974:   4%|▍         | 5/112 [00:08<02:57,  1.65s/it]
# Epochs 7/10. Running Loss:    0.3974:   5%|▌         | 6/112 [00:09<02:56,  1.66s/it]
# Epochs 7/10. Running Loss:    0.3355:   5%|▌         | 6/112 [00:10<02:56,  1.66s/it]
# Epochs 7/10. Running Loss:    0.3355:   6%|▋         | 7/112 [00:11<02:54,  1.66s/it]
# Epochs 7/10. Running Loss:    0.6402:   6%|▋         | 7/112 [00:12<02:54,  1.66s/it]
# Epochs 7/10. Running Loss:    0.6402:   7%|▋         | 8/112 [00:13<02:52,  1.66s/it]
# Epochs 7/10. Running Loss:    0.6539:   7%|▋         | 8/112 [00:13<02:52,  1.66s/it]
# Epochs 7/10. Running Loss:    0.6539:   8%|▊         | 9/112 [00:14<02:50,  1.66s/it]
# Epochs 7/10. Running Loss:    0.6387:   8%|▊         | 9/112 [00:15<02:50,  1.66s/it]
# Epochs 7/10. Running Loss:    0.6387:   9%|▉         | 10/112 [00:16<02:49,  1.66s/it]
# Epochs 7/10. Running Loss:    0.5682:   9%|▉         | 10/112 [00:17<02:49,  1.66s/it]
# Epochs 7/10. Running Loss:    0.5682:  10%|▉         | 11/112 [00:18<02:47,  1.66s/it]
# Epochs 7/10. Running Loss:    0.6205:  10%|▉         | 11/112 [00:18<02:47,  1.66s/it]
# Epochs 7/10. Running Loss:    0.6205:  11%|█         | 12/112 [00:19<02:46,  1.66s/it]
# Epochs 7/10. Running Loss:    0.5032:  11%|█         | 12/112 [00:20<02:46,  1.66s/it]
# Epochs 7/10. Running Loss:    0.5032:  12%|█▏        | 13/112 [00:21<02:44,  1.66s/it]
# Epochs 7/10. Running Loss:    0.4450:  12%|█▏        | 13/112 [00:22<02:44,  1.66s/it]
# Epochs 7/10. Running Loss:    0.4450:  12%|█▎        | 14/112 [00:23<02:42,  1.66s/it]
# Epochs 7/10. Running Loss:    0.7173:  12%|█▎        | 14/112 [00:23<02:42,  1.66s/it]
# Epochs 7/10. Running Loss:    0.7173:  13%|█▎        | 15/112 [00:24<02:41,  1.66s/it]
# Epochs 7/10. Running Loss:    0.5674:  13%|█▎        | 15/112 [00:25<02:41,  1.66s/it]
# Epochs 7/10. Running Loss:    0.5674:  14%|█▍        | 16/112 [00:26<02:38,  1.66s/it]
# Epochs 7/10. Running Loss:    0.6682:  14%|█▍        | 16/112 [00:27<02:38,  1.66s/it]
# Epochs 7/10. Running Loss:    0.6682:  15%|█▌        | 17/112 [00:28<02:38,  1.67s/it]
# Epochs 7/10. Running Loss:    0.6756:  15%|█▌        | 17/112 [00:28<02:38,  1.67s/it]
# Epochs 7/10. Running Loss:    0.6756:  16%|█▌        | 18/112 [00:29<02:36,  1.66s/it]
# Epochs 7/10. Running Loss:    0.4591:  16%|█▌        | 18/112 [00:30<02:36,  1.66s/it]
# Epochs 7/10. Running Loss:    0.4591:  17%|█▋        | 19/112 [00:31<02:34,  1.66s/it]
# Epochs 7/10. Running Loss:    0.5063:  17%|█▋        | 19/112 [00:32<02:34,  1.66s/it]
# Epochs 7/10. Running Loss:    0.5063:  18%|█▊        | 20/112 [00:33<02:32,  1.66s/it]
# Epochs 7/10. Running Loss:    0.3202:  18%|█▊        | 20/112 [00:33<02:32,  1.66s/it]
# Epochs 7/10. Running Loss:    0.3202:  19%|█▉        | 21/112 [00:34<02:31,  1.67s/it]
# Epochs 7/10. Running Loss:    0.4635:  19%|█▉        | 21/112 [00:35<02:31,  1.67s/it]
# Epochs 7/10. Running Loss:    0.4635:  20%|█▉        | 22/112 [00:36<02:29,  1.66s/it]
# Epochs 7/10. Running Loss:    0.5668:  20%|█▉        | 22/112 [00:37<02:29,  1.66s/it]
# Epochs 7/10. Running Loss:    0.5668:  21%|██        | 23/112 [00:38<02:27,  1.66s/it]
# Epochs 7/10. Running Loss:    0.3770:  21%|██        | 23/112 [00:38<02:27,  1.66s/it]
# Epochs 7/10. Running Loss:    0.3770:  21%|██▏       | 24/112 [00:39<02:26,  1.66s/it]
# Epochs 7/10. Running Loss:    0.3684:  21%|██▏       | 24/112 [00:40<02:26,  1.66s/it]
# Epochs 7/10. Running Loss:    0.3684:  22%|██▏       | 25/112 [00:41<02:24,  1.66s/it]
# Epochs 7/10. Running Loss:    0.4701:  22%|██▏       | 25/112 [00:42<02:24,  1.66s/it]
# Epochs 7/10. Running Loss:    0.4701:  23%|██▎       | 26/112 [00:43<02:23,  1.66s/it]
# Epochs 7/10. Running Loss:    0.4918:  23%|██▎       | 26/112 [00:43<02:23,  1.66s/it]
# Epochs 7/10. Running Loss:    0.4918:  24%|██▍       | 27/112 [00:44<02:21,  1.66s/it]
# Epochs 7/10. Running Loss:    0.4892:  24%|██▍       | 27/112 [00:45<02:21,  1.66s/it]
# Epochs 7/10. Running Loss:    0.4892:  25%|██▌       | 28/112 [00:46<02:19,  1.66s/it]
# Epochs 7/10. Running Loss:    0.4941:  25%|██▌       | 28/112 [00:47<02:19,  1.66s/it]
# Epochs 7/10. Running Loss:    0.4941:  26%|██▌       | 29/112 [00:48<02:18,  1.66s/it]
# Epochs 7/10. Running Loss:    0.4189:  26%|██▌       | 29/112 [00:48<02:18,  1.66s/it]
# Epochs 7/10. Running Loss:    0.4189:  27%|██▋       | 30/112 [00:49<02:16,  1.67s/it]
# Epochs 7/10. Running Loss:    0.5252:  27%|██▋       | 30/112 [00:50<02:16,  1.67s/it]
# Epochs 7/10. Running Loss:    0.5252:  28%|██▊       | 31/112 [00:51<02:14,  1.67s/it]
# Epochs 7/10. Running Loss:    0.6232:  28%|██▊       | 31/112 [00:52<02:14,  1.67s/it]C:\Users\Precision5570\anaconda3\envs\TextMining5\Lib\site-packages\simpletransformers\classification\classification_model.py:1452: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   warnings.warn(
#
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# 2it [00:11,  5.80s/it]
#
# Epochs 7/10. Running Loss:    0.6232:  29%|██▊       | 32/112 [01:10<09:09,  6.87s/it]
# Epochs 7/10. Running Loss:    0.3989:  29%|██▊       | 32/112 [01:11<09:09,  6.87s/it]
# Epochs 7/10. Running Loss:    0.3989:  29%|██▉       | 33/112 [01:12<06:58,  5.30s/it]
# Epochs 7/10. Running Loss:    0.7089:  29%|██▉       | 33/112 [01:12<06:58,  5.30s/it]
# Epochs 7/10. Running Loss:    0.7089:  30%|███       | 34/112 [01:13<05:28,  4.21s/it]
# Epochs 7/10. Running Loss:    0.4838:  30%|███       | 34/112 [01:14<05:28,  4.21s/it]
# Epochs 7/10. Running Loss:    0.4838:  31%|███▏      | 35/112 [01:15<04:25,  3.45s/it]
# Epochs 7/10. Running Loss:    0.6553:  31%|███▏      | 35/112 [01:16<04:25,  3.45s/it]
# Epochs 7/10. Running Loss:    0.6553:  32%|███▏      | 36/112 [01:17<03:41,  2.92s/it]
# Epochs 7/10. Running Loss:    0.5880:  32%|███▏      | 36/112 [01:17<03:41,  2.92s/it]
# Epochs 7/10. Running Loss:    0.5880:  33%|███▎      | 37/112 [01:18<03:10,  2.54s/it]
# Epochs 7/10. Running Loss:    0.6434:  33%|███▎      | 37/112 [01:19<03:10,  2.54s/it]
# Epochs 7/10. Running Loss:    0.6434:  34%|███▍      | 38/112 [01:20<02:48,  2.27s/it]
# Epochs 7/10. Running Loss:    0.3440:  34%|███▍      | 38/112 [01:21<02:48,  2.27s/it]
# Epochs 7/10. Running Loss:    0.3440:  35%|███▍      | 39/112 [01:22<02:32,  2.09s/it]
# Epochs 7/10. Running Loss:    0.5668:  35%|███▍      | 39/112 [01:22<02:32,  2.09s/it]
# Epochs 7/10. Running Loss:    0.5668:  36%|███▌      | 40/112 [01:23<02:21,  1.96s/it]
# Epochs 7/10. Running Loss:    0.4729:  36%|███▌      | 40/112 [01:24<02:21,  1.96s/it]
# Epochs 7/10. Running Loss:    0.4729:  37%|███▋      | 41/112 [01:25<02:12,  1.87s/it]
# Epochs 7/10. Running Loss:    0.4660:  37%|███▋      | 41/112 [01:26<02:12,  1.87s/it]
# Epochs 7/10. Running Loss:    0.4660:  38%|███▊      | 42/112 [01:27<02:06,  1.81s/it]
# Epochs 7/10. Running Loss:    0.4214:  38%|███▊      | 42/112 [01:27<02:06,  1.81s/it]
# Epochs 7/10. Running Loss:    0.4214:  38%|███▊      | 43/112 [01:28<02:01,  1.76s/it]
# Epochs 7/10. Running Loss:    0.5309:  38%|███▊      | 43/112 [01:29<02:01,  1.76s/it]
# Epochs 7/10. Running Loss:    0.5309:  39%|███▉      | 44/112 [01:30<01:57,  1.74s/it]
# Epochs 7/10. Running Loss:    0.5842:  39%|███▉      | 44/112 [01:31<01:57,  1.74s/it]
# Epochs 7/10. Running Loss:    0.5842:  40%|████      | 45/112 [01:32<01:54,  1.71s/it]
# Epochs 7/10. Running Loss:    0.6131:  40%|████      | 45/112 [01:32<01:54,  1.71s/it]
# Epochs 7/10. Running Loss:    0.6131:  41%|████      | 46/112 [01:33<01:51,  1.69s/it]
# Epochs 7/10. Running Loss:    0.5467:  41%|████      | 46/112 [01:34<01:51,  1.69s/it]
# Epochs 7/10. Running Loss:    0.5467:  42%|████▏     | 47/112 [01:35<01:49,  1.68s/it]
# Epochs 7/10. Running Loss:    0.4950:  42%|████▏     | 47/112 [01:36<01:49,  1.68s/it]
# Epochs 7/10. Running Loss:    0.4950:  43%|████▎     | 48/112 [01:37<01:47,  1.68s/it]
# Epochs 7/10. Running Loss:    0.4867:  43%|████▎     | 48/112 [01:37<01:47,  1.68s/it]
# Epochs 7/10. Running Loss:    0.4867:  44%|████▍     | 49/112 [01:38<01:45,  1.68s/it]
# Epochs 7/10. Running Loss:    0.3090:  44%|████▍     | 49/112 [01:39<01:45,  1.68s/it]
# Epochs 7/10. Running Loss:    0.3090:  45%|████▍     | 50/112 [01:40<01:43,  1.67s/it]
# Epochs 7/10. Running Loss:    0.4844:  45%|████▍     | 50/112 [01:41<01:43,  1.67s/it]
# Epochs 7/10. Running Loss:    0.4844:  46%|████▌     | 51/112 [01:42<01:41,  1.66s/it]
# Epochs 7/10. Running Loss:    0.4260:  46%|████▌     | 51/112 [01:42<01:41,  1.66s/it]
# Epochs 7/10. Running Loss:    0.4260:  46%|████▋     | 52/112 [01:43<01:40,  1.67s/it]
# Epochs 7/10. Running Loss:    0.5210:  46%|████▋     | 52/112 [01:44<01:40,  1.67s/it]
# Epochs 7/10. Running Loss:    0.5210:  47%|████▋     | 53/112 [01:45<01:38,  1.67s/it]
# Epochs 7/10. Running Loss:    0.4409:  47%|████▋     | 53/112 [01:45<01:38,  1.67s/it]
# Epochs 7/10. Running Loss:    0.4409:  48%|████▊     | 54/112 [01:47<01:36,  1.66s/it]
# Epochs 7/10. Running Loss:    0.3866:  48%|████▊     | 54/112 [01:47<01:36,  1.66s/it]
# Epochs 7/10. Running Loss:    0.3866:  49%|████▉     | 55/112 [01:48<01:34,  1.66s/it]
# Epochs 7/10. Running Loss:    0.4333:  49%|████▉     | 55/112 [01:49<01:34,  1.66s/it]
# Epochs 7/10. Running Loss:    0.4333:  50%|█████     | 56/112 [01:50<01:33,  1.66s/it]
# Epochs 7/10. Running Loss:    0.5508:  50%|█████     | 56/112 [01:50<01:33,  1.66s/it]
# Epochs 7/10. Running Loss:    0.5508:  51%|█████     | 57/112 [01:52<01:31,  1.66s/it]
# Epochs 7/10. Running Loss:    0.3946:  51%|█████     | 57/112 [01:52<01:31,  1.66s/it]
# Epochs 7/10. Running Loss:    0.3946:  52%|█████▏    | 58/112 [01:53<01:29,  1.66s/it]
# Epochs 7/10. Running Loss:    0.6054:  52%|█████▏    | 58/112 [01:54<01:29,  1.66s/it]
# Epochs 7/10. Running Loss:    0.6054:  53%|█████▎    | 59/112 [01:55<01:28,  1.66s/it]
# Epochs 7/10. Running Loss:    0.4084:  53%|█████▎    | 59/112 [01:55<01:28,  1.66s/it]
# Epochs 7/10. Running Loss:    0.4084:  54%|█████▎    | 60/112 [01:57<01:26,  1.66s/it]
# Epochs 7/10. Running Loss:    0.7573:  54%|█████▎    | 60/112 [01:57<01:26,  1.66s/it]
# Epochs 7/10. Running Loss:    0.7573:  54%|█████▍    | 61/112 [01:58<01:25,  1.67s/it]
# Epochs 7/10. Running Loss:    0.4279:  54%|█████▍    | 61/112 [01:59<01:25,  1.67s/it]
# Epochs 7/10. Running Loss:    0.4279:  55%|█████▌    | 62/112 [02:00<01:23,  1.67s/it]
# Epochs 7/10. Running Loss:    0.5222:  55%|█████▌    | 62/112 [02:00<01:23,  1.67s/it]
# Epochs 7/10. Running Loss:    0.5222:  56%|█████▋    | 63/112 [02:02<01:21,  1.67s/it]
# Epochs 7/10. Running Loss:    0.3963:  56%|█████▋    | 63/112 [02:02<01:21,  1.67s/it]C:\Users\Precision5570\anaconda3\envs\TextMining5\Lib\site-packages\simpletransformers\classification\classification_model.py:1452: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   warnings.warn(
#
#
#   0%|          | 0/1 [00:00<?, ?it/s]
#
# 2it [00:11,  5.85s/it]
# Epoch 7 of 10:  60%|██████    | 6/10 [30:36<20:24, 306.05s/it]
# Epochs 7/10. Running Loss:    0.3963:  56%|█████▋    | 63/112 [02:21<01:49,  2.24s/it]

# %%
for index, row in df_test.iterrows():
    if row['sentiment'] in mapping:
        df_test.at[index, 'sentiment'] = mapping[row['sentiment']]

df_test

predicted, probabilities = model.predict(df_test.text.to_list())
df_test['predicted_sentiment'] = predicted

df_test
# Out:
# 1it [00:11, 11.44s/it]
# 100%|██████████| 1/1 [00:00<00:00,  2.76it/s]
#    sentence id                                               text sentiment  \
# 0            0  I wouldn't be caught dead watching the NFL if ...         0
# 1            1  Chris O'Donnell stated that while filming for ...         2
# 2            2  The whole game was a rollercoaster ride, but L...         1
# 3            3  Zendaya slayed in Dune 2, as she does in all h...         1
# 4            4  While my favorite player was playing this matc...         0
# 5            5  My uncle's brother's neighbor's cat's veterina...         2
# 6            6  He said that The Great Gatsby is the best nove...         0
# 7            7  I could not look away from this train wrck of ...         0
# 8            8  The film Everything Everywhere All At Once fol...         2
# 9            9  I just finished reading pride and prejudice wh...         1
#
#     topic  Predicted Topic  Predicted_Topic_LDA Predicted_Topic_MNB  \
# 0  sports                1                    1               movie
# 1   movie                1                    1               movie
# 2  sports                1                    1              sports
# 3   movie                1                    1               movie
# 4  sports                1                    1              sports
# 5    book                1                    1               movie
# 6    book                1                    1               movie
# 7   movie                1                    1               movie
# 8   movie                1                    1               movie
# 9    book                1                    1                book
#
#    predicted_sentiment
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    1
# 5                    0
# 6                    1
# 7                    0
# 8                    0
# 9                    0
